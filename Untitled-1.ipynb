# %%
print('k')
# Out:
# k

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, log_loss, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint
from sklearn.metrics import confusion_matrix

# %%
ice = pd.read_excel('./iscream(크롤링).xlsx')

# %%
if 'Unnamed: 0' in ice.columns:
    ice = ice.drop(columns=['Unnamed: 0'])

ice = ice.dropna(subset=['별점'])

# 별점 기준 라벨링:5점은 긍정(1), 1-4점은 부정(0)
ice['label'] = ice['별점'].apply(lambda x: 1 if x > 4 else 0)

# %%
from konlpy.tag import Okt
okt = Okt()
stop_words = set(['에게','함께','미술','이야기','하면','제','활동','있어서','어떻게','버전','유튜브','페이지','패들렛','사이트','다소','릿','각도','하시','안배','그림','특별','사람','표현','됩니다','평소','강','있게','이번','되고','현장','그림책','참','우리','꼭','있어','있었습니다','연','하는데','아이스크림','하며','하면서','학년','관련','되는','저','여행','게','영어','대해','시간','생각','노션','후기','였습니다','되었습니다','합니다','학기','했습니다','우리나라','너무나','부터','후기','만','통해','화용론','아이','감사합니다','많은','그게','여학생','남학생','듣고','것', '너무','있는','하는','에서','로','더','을','학생','대한','많이','내용','마음','하고','감사','정말','수업','강의','연수','할','수','적','인','분','입니다','의', '가', '이', '은', '들', '는', '좀', '잘', '걍', '과', '도', '를', '으로', '자', '에', '와', '한', '하다'])

# %%
#긍정 2575, 부정100
import matplotlib.pyplot as plt

value_counts = ice['label'].value_counts()

ax = value_counts.plot(kind='bar')


for i, v in enumerate(value_counts):
    ax.text(i, v + 10, str(v), ha='center', va='bottom')
plt.show()

# %%
tfidf = TfidfVectorizer()
data_input_reduced= tfidf.fit_transform(ice['리뷰내용'])
data_target = ice['label']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, log_loss, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer



sample_sizes = range(200, 500, 100)
train_accuracy_results = []
test_accuracy_results = []
cv_accuracy_results = []
recall_results = []
precision_results = []
f1_results = []
train_loss_results = []
test_loss_results = []

# 고정된 random_state를 사용하여 데이터 샘플링 유지
for size in sample_sizes:
    # 언더샘플링
    Training_data_0 = ice[ice['label'] == 0]
    Training_data_1 = ice[ice['label'] == 1].sample(size, random_state=41)
    Undersample_data = pd.concat([Training_data_0, Training_data_1]).sample(frac=1, random_state=41).reset_index(drop=True)

    # 특성과 타겟 변수 분리
    tfidf = TfidfVectorizer()
    data_input_reduced = tfidf.fit_transform(Undersample_data['리뷰내용'])
    data_target = Undersample_data['label']

    X_train, X_test, y_train, y_test = train_test_split(data_input_reduced, data_target, test_size=0.2, random_state=42)

    # 랜덤 포레스트 모델 정의
    rf = RandomForestClassifier(random_state=42)

    # 그리드 서치 파라미터 설정
    param_grid = {
        'n_estimators': [100, 150, 200],  # 적절한 수의 나무
        'max_depth': [10, 20, 30, 40],    # 최대 깊이 제한
        'min_samples_split': [5, 10, 15], # 분할에 필요한 최소 샘플 수
        'min_samples_leaf': [2, 4, 6],    # 리프 노드에 필요한 최소 샘플 수
        'bootstrap': [True, False]        # 부트스트래핑 여부
    }

    # 그리드 서치 정의
    grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, verbose=2, n_jobs=-1, scoring='accuracy')

    # 그리드 서치 학습
    grid_search.fit(X_train, y_train)

    # 최적의 하이퍼파라미터 출력
    print(f"Best parameters found: {grid_search.best_params_}")

    # 최적 모델로 예측
    best_rf = grid_search.best_estimator_
    y_train_pred = best_rf.predict(X_train)
    y_test_pred = best_rf.predict(X_test)

    # 평가
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    train_loss = log_loss(y_train, best_rf.predict_proba(X_train))
    test_loss = log_loss(y_test, best_rf.predict_proba(X_test))
    recall = recall_score(y_test, y_test_pred)
    precision = precision_score(y_test, y_test_pred)
    f1 = f1_score(y_test, y_test_pred)
    cv_accuracy = cross_val_score(best_rf, X_train, y_train, cv=5, scoring='accuracy').mean()

    train_accuracy_results.append(train_accuracy)
    test_accuracy_results.append(test_accuracy)
    cv_accuracy_results.append(cv_accuracy)
    recall_results.append(recall)
    precision_results.append(precision)
    f1_results.append(f1)
    train_loss_results.append(train_loss)
    test_loss_results.append(test_loss)

    target_counts = y_test.value_counts()

    # 혼동 행렬 계산
    conf_matrix = confusion_matrix(y_test, y_test_pred)

    # 혼동 행렬 시각화
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

    # 시각화
    plt.figure(figsize=(10, 6))
    plt.plot(sample_sizes, train_accuracy_results, marker='o', label='Train Accuracy')
    plt.plot(sample_sizes, test_accuracy_results, marker='o', label='Test Accuracy')
    plt.plot(sample_sizes, cv_accuracy_results, marker='o', label='Cross-Validation Accuracy')
    plt.plot(sample_sizes, recall_results, marker='o', label='Recall')
    plt.plot(sample_sizes, precision_results, marker='o', label='Precision')
    plt.plot(sample_sizes, f1_results, marker='o', label='F1 Score')
    plt.plot(sample_sizes, train_loss_results, marker='o', label='Train Loss')
    plt.plot(sample_sizes, test_loss_results, marker='o', label='Test Loss')
    plt.xlabel('Sample Size')
    plt.ylabel('Score')
    plt.title('Model Performance vs. Sample Size')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': False, 'max_depth': 40, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 96
#      94 # 시각화
#      95 plt.figure(figsize=(10, 6))
# ---> 96 plt.plot(sample_sizes, train_accuracy_results, marker='o', label='Train Accuracy')
#      97 plt.plot(sample_sizes, test_accuracy_results, marker='o', label='Test Accuracy')
#      98 plt.plot(sample_sizes, cv_accuracy_results, marker='o', label='Cross-Validation Accuracy')
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (3,) and (1,)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, log_loss, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer


sample_sizes = range(200, 800, 100)
train_accuracy_results = []
test_accuracy_results = []
cv_accuracy_results = []
recall_results = []
precision_results = []
f1_results = []
train_loss_results = []
test_loss_results = []

# 고정된 random_state를 사용하여 데이터 샘플링 유지
for size in sample_sizes:
    # 언더샘플링
    Training_data_0 = ice[ice['label'] == 0]
    Training_data_1 = ice[ice['label'] == 1].sample(size, random_state=41)
    Undersample_data = pd.concat([Training_data_0, Training_data_1]).sample(frac=1, random_state=41).reset_index(drop=True)

    # 특성과 타겟 변수 분리
    tfidf = TfidfVectorizer()
    data_input_reduced = tfidf.fit_transform(Undersample_data['리뷰내용'])
    data_target = Undersample_data['label']

    X_train, X_test, y_train, y_test = train_test_split(data_input_reduced, data_target, test_size=0.2, random_state=42)

    # 랜덤 포레스트 모델 정의
    rf = RandomForestClassifier(random_state=42)

    # 그리드 서치 파라미터 설정
    param_grid = {
        'n_estimators': [100, 150, 200],  # 적절한 수의 나무
        'max_depth': [10, 20, 30, 40],    # 최대 깊이 제한
        'min_samples_split': [5, 10, 15], # 분할에 필요한 최소 샘플 수
        'min_samples_leaf': [2, 4, 6],    # 리프 노드에 필요한 최소 샘플 수
        'bootstrap': [True, False]        # 부트스트래핑 여부
    }

    # 그리드 서치 정의
    grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, verbose=2, n_jobs=-1, scoring='accuracy')

    # 그리드 서치 학습
    grid_search.fit(X_train, y_train)

    # 최적의 하이퍼파라미터 출력
    print(f"Best parameters found: {grid_search.best_params_}")

    # 최적 모델로 예측
    best_rf = grid_search.best_estimator_
    y_train_pred = best_rf.predict(X_train)
    y_test_pred = best_rf.predict(X_test)

    # 평가
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    train_loss = log_loss(y_train, best_rf.predict_proba(X_train))
    test_loss = log_loss(y_test, best_rf.predict_proba(X_test))
    recall = recall_score(y_test, y_test_pred)
    precision = precision_score(y_test, y_test_pred)
    f1 = f1_score(y_test, y_test_pred)
    cv_accuracy = cross_val_score(best_rf, X_train, y_train, cv=5, scoring='accuracy').mean()

    train_accuracy_results.append(train_accuracy)
    test_accuracy_results.append(test_accuracy)
    cv_accuracy_results.append(cv_accuracy)
    recall_results.append(recall)
    precision_results.append(precision)
    f1_results.append(f1)
    train_loss_results.append(train_loss)
    test_loss_results.append(test_loss)

    # 혼동 행렬 계산
    conf_matrix = confusion_matrix(y_test, y_test_pred)

    # 혼동 행렬 시각화
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# 시각화
plt.figure(figsize=(10, 6))
plt.plot(sample_sizes, train_accuracy_results, marker='o', label='Train Accuracy')
plt.plot(sample_sizes, test_accuracy_results, marker='o', label='Test Accuracy')
plt.plot(sample_sizes, cv_accuracy_results, marker='o', label='Cross-Validation Accuracy')
plt.plot(sample_sizes, recall_results, marker='o', label='Recall')
plt.plot(sample_sizes, precision_results, marker='o', label='Precision')
plt.plot(sample_sizes, f1_results, marker='o', label='F1 Score')
plt.plot(sample_sizes, train_loss_results, marker='o', label='Train Loss')
plt.plot(sample_sizes, test_loss_results, marker='o', label='Test Loss')
plt.xlabel('Sample Size')
plt.ylabel('Score')
plt.title('Model Performance vs. Sample Size')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': False, 'max_depth': 40, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': False, 'max_depth': 40, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': False, 'max_depth': 40, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, log_loss, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer


train_accuracy_results = []
test_accuracy_results = []
cv_accuracy_results = []
recall_results = []
precision_results = []
f1_results = []
train_loss_results = []
test_loss_results = []

# 고정된 random_state를 사용하여 데이터 샘플링 유지

    # 언더샘플링
Training_data_0 = ice[ice['label'] == 0]
Training_data_1 = ice[ice['label'] == 1].sample(600, random_state=41)
Undersample_data = pd.concat([Training_data_0, Training_data_1]).sample(frac=1, random_state=41).reset_index(drop=True)

# 특성과 타겟 변수 분리
tfidf = TfidfVectorizer()
data_input_reduced = tfidf.fit_transform(Undersample_data['리뷰내용'])
data_target = Undersample_data['label']

X_train, X_test, y_train, y_test = train_test_split(data_input_reduced, data_target, test_size=0.2, random_state=42)

# 랜덤 포레스트 모델 정의
rf = RandomForestClassifier(random_state=42)

# 그리드 서치 파라미터 설정
param_grid = {
    'n_estimators': [100, 150, 200],  # 적절한 수의 나무
    'max_depth': [10, 20, 30, 40],    # 최대 깊이 제한
    'min_samples_split': [5, 10, 15], # 분할에 필요한 최소 샘플 수
    'min_samples_leaf': [2, 4, 6],    # 리프 노드에 필요한 최소 샘플 수
    'bootstrap': [True, False]        # 부트스트래핑 여부
}

# 그리드 서치 정의
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, verbose=2, n_jobs=-1, scoring='accuracy')

# 그리드 서치 학습
grid_search.fit(X_train, y_train)

# 최적의 하이퍼파라미터 출력
print(f"Best parameters found: {grid_search.best_params_}")

# 최적 모델로 예측
best_rf = grid_search.best_estimator_
y_train_pred = best_rf.predict(X_train)
y_test_pred = best_rf.predict(X_test)

# 평가
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
train_loss = log_loss(y_train, best_rf.predict_proba(X_train))
test_loss = log_loss(y_test, best_rf.predict_proba(X_test))
recall = recall_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)
cv_accuracy = cross_val_score(best_rf, X_train, y_train, cv=5, scoring='accuracy').mean()

train_accuracy_results.append(train_accuracy)
test_accuracy_results.append(test_accuracy)
cv_accuracy_results.append(cv_accuracy)
recall_results.append(recall)
precision_results.append(precision)
f1_results.append(f1)
train_loss_results.append(train_loss)
test_loss_results.append(test_loss)

# 혼동 행렬 계산
conf_matrix = confusion_matrix(y_test, y_test_pred)

# 혼동 행렬 시각화
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# 시각화
plt.figure(figsize=(10, 6))
plt.plot(sample_sizes, train_accuracy_results, marker='o', label='Train Accuracy')
plt.plot(sample_sizes, test_accuracy_results, marker='o', label='Test Accuracy')
plt.plot(sample_sizes, cv_accuracy_results, marker='o', label='Cross-Validation Accuracy')
plt.plot(sample_sizes, recall_results, marker='o', label='Recall')
plt.plot(sample_sizes, precision_results, marker='o', label='Precision')
plt.plot(sample_sizes, f1_results, marker='o', label='F1 Score')
plt.plot(sample_sizes, train_loss_results, marker='o', label='Train Loss')
plt.plot(sample_sizes, test_loss_results, marker='o', label='Test Loss')
plt.xlabel('Sample Size')
plt.ylabel('Score')
plt.title('Model Performance vs. Sample Size')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# Best parameters found: {'bootstrap': False, 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 92
#      90 # 시각화
#      91 plt.figure(figsize=(10, 6))
# ---> 92 plt.plot(sample_sizes, train_accuracy_results, marker='o', label='Train Accuracy')
#      93 plt.plot(sample_sizes, test_accuracy_results, marker='o', label='Test Accuracy')
#      94 plt.plot(sample_sizes, cv_accuracy_results, marker='o', label='Cross-Validation Accuracy')
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (23,) and (1,)

# %%
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd


# 리뷰내용 컬럼의 모든 텍스트를 가져옴
reviews = ice['리뷰내용'].tolist()

okt = Okt()

# 모든 문서의 명사 추출 후 하나의 텍스트로 결합
processed_docs = []
for doc in reviews:
    nouns = okt.nouns(doc)
    processed_docs.append(" ".join(nouns))

# TF-IDF 벡터화 객체 생성
vectorizer = TfidfVectorizer()

# 텍스트를 TF-IDF로 변환
tfidf_matrix = vectorizer.fit_transform(processed_docs)

# 단어와 그에 대한 TF-IDF 값을 얻기
feature_names = vectorizer.get_feature_names_out()
tfidf_values = tfidf_matrix.toarray()

# 각 문서의 상위 5개 키워드 추출
top_keywords = []
for doc_index in range(len(reviews)):
    doc_tfidf_values = tfidf_values[doc_index]
    sorted_indices = sorted(range(len(doc_tfidf_values)), key=lambda k: doc_tfidf_values[k], reverse=True)
    top_keywords.append([feature_names[i] for i in sorted_indices[:5]])

# 결과 출력
for i, keywords in enumerate(top_keywords):
    print(f"문서 {i+1}의 상위 키워드: {keywords}")
# Out:
# 문서 1의 상위 키워드: ['배기', '쏭쌤', '종대', '알짜', '다음']
# 문서 2의 상위 키워드: ['글씨', '연습', '교재', '뱃지', '액자']
# 문서 3의 상위 키워드: ['학력', '소개', '기초', '도움', '사이트']
# 문서 4의 상위 키워드: ['이슈', '바르게', '이해', '차이', '배경']
# 문서 5의 상위 키워드: ['일본어', '성우', '양어', '존경어', '사료']
# 문서 6의 상위 키워드: ['형식', '느낌', '이야기', '강의', '가게']
# 문서 7의 상위 키워드: ['고전', '부여', '해석', '나름', '의미']
# 문서 8의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 9의 상위 키워드: ['교육과정', '토대', '개정', '대략', '교과서']
# 문서 10의 상위 키워드: ['대비', '직업', '미래', '학생', '대해']
# 문서 11의 상위 키워드: ['개념', '실제', '대한', '이해', '도움']
# 문서 12의 상위 키워드: ['미래', '교육', '분야', '생각', '가게']
# 문서 13의 상위 키워드: ['코이카', '사례', '가게', '가격', '가공']
# 문서 14의 상위 키워드: ['정재승', '교수', '공부', '시간', '대해']
# 문서 15의 상위 키워드: ['웹툰', '내용', '이해', '연수', '가게']
# 문서 16의 상위 키워드: ['잡기', '시민', '개념', '세계', '사례']
# 문서 17의 상위 키워드: ['열기', '작업', '고학년', '상담', '마음']
# 문서 18의 상위 키워드: ['원인', '유형', '부진', '별로', '학습']
# 문서 19의 상위 키워드: ['추천', '연수', '가게', '가격', '가공']
# 문서 20의 상위 키워드: ['요새', '관심사', '추천', '연수', '가게']
# 문서 21의 상위 키워드: ['알베르토', '다문화', '교육', '가게', '가격']
# 문서 22의 상위 키워드: ['생각', '대화', '부분', '고집', '손절']
# 문서 23의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 24의 상위 키워드: ['사회', '씨름', '조차', '언어', '재테크']
# 문서 25의 상위 키워드: ['만해', '명성', '김성규', '역시', '평소']
# 문서 26의 상위 키워드: ['배기', '알짜', '왕초보', '내용', '연수']
# 문서 27의 상위 키워드: ['특수', '교사', '경력', '동향', '두루']
# 문서 28의 상위 키워드: ['혼자', '단어', '연수', '문제', '신청']
# 문서 29의 상위 키워드: ['브루', '장면', '참고', '교실', '실제']
# 문서 30의 상위 키워드: ['최태성', '깊이', '흥미', '덕분', '한국사']
# 문서 31의 상위 키워드: ['사용', '기기', '스마트', '필요성', '또한']
# 문서 32의 상위 키워드: ['작용', '우리', '사람', '시간', '대해']
# 문서 33의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 34의 상위 키워드: ['기초', '이해', '활용', '수업', '도움']
# 문서 35의 상위 키워드: ['정재승', '교수', '설명', '이해', '도움']
# 문서 36의 상위 키워드: ['최태성', '이수', '역사', '공부', '선생님']
# 문서 37의 상위 키워드: ['초등학교', '고학년', '담임', '한국사', '현장']
# 문서 38의 상위 키워드: ['통합', '담임', '기본', '학급', '적용']
# 문서 39의 상위 키워드: ['고민', '대해', '활용', '연수', '가게']
# 문서 40의 상위 키워드: ['인권', '대해', '생각', '연수', '가게']
# 문서 41의 상위 키워드: ['게임', '수업', '기능', '기회', '학습']
# 문서 42의 상위 키워드: ['위로', '지금', '기본', '마음', '연수']
# 문서 43의 상위 키워드: ['부담', '솜씨', '모임', '마음', '갈수록']
# 문서 44의 상위 키워드: ['활동', '여가', '일환', '교과', '정보']
# 문서 45의 상위 키워드: ['아이스크림', '에듀', '테크', '유료', '회원']
# 문서 46의 상위 키워드: ['인공', '지능', '교육', '활용', '연수']
# 문서 47의 상위 키워드: ['캘리그래피', '쓰기', '글씨', '힐링', '시간']
# 문서 48의 상위 키워드: ['중요성', '한번', '정리', '다시', '연수']
# 문서 49의 상위 키워드: ['경북', '교육청', '감사', '연수', '가게']
# 문서 50의 상위 키워드: ['무장', '실전', '이론', '가게', '가격']
# 문서 51의 상위 키워드: ['에듀', '테크', '공부', '정말', '수업']
# 문서 52의 상위 키워드: ['실생활', '연수', '가게', '가격', '가공']
# 문서 53의 상위 키워드: ['모양', '글씨', '여러', '가지', '실제']
# 문서 54의 상위 키워드: ['해결', '부담', '추천', '연수', '가게']
# 문서 55의 상위 키워드: ['입문', '재테크', '현실', '교사', '추천']
# 문서 56의 상위 키워드: ['홍수', '정보', '무엇', '고민', '정말']
# 문서 57의 상위 키워드: ['사용', '추천', '가게', '가격', '가공']
# 문서 58의 상위 키워드: ['완료', '접목', '이수', '현장', '이해']
# 문서 59의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 60의 상위 키워드: ['아동', '특수', '기회', '이해', '연수']
# 문서 61의 상위 키워드: ['중국어', '공부', '귀가', '벌써', '어학']
# 문서 62의 상위 키워드: ['문해', '지식', '기초', '이해', '강의']
# 문서 63의 상위 키워드: ['내용', '직접', '공부', '방법', '대한']
# 문서 64의 상위 키워드: ['계곡', '고통', '봉우리', '약물', '치료']
# 문서 65의 상위 키워드: ['력도', '반성', '분야', '정보', '영어']
# 문서 66의 상위 키워드: ['력도', '반성', '분야', '정보', '영어']
# 문서 67의 상위 키워드: ['한국사', '연수', '가게', '가격', '가공']
# 문서 68의 상위 키워드: ['마음속', '햇빛', '종종', '바람', '매년']
# 문서 69의 상위 키워드: ['학생', '장애', '일반', '특수', '학부모']
# 문서 70의 상위 키워드: ['진로', '교육', '학생', '시간', '활용']
# 문서 71의 상위 키워드: ['매일', '체계', '영어', '공부', '가게']
# 문서 72의 상위 키워드: ['경영', '듣기', '놀이', '학급', '적용']
# 문서 73의 상위 키워드: ['용도', '고학년', '저학년', '가게', '가격']
# 문서 74의 상위 키워드: ['재테크', '부자', '교사', '내용', '생각']
# 문서 75의 상위 키워드: ['언어', '우리나라', '대한', '연수', '가게']
# 문서 76의 상위 키워드: ['재테크', '내용', '생각', '도움', '가게']
# 문서 77의 상위 키워드: ['미국인', '용도', '주제', '생활', '가게']
# 문서 78의 상위 키워드: ['내용', '강의', '가게', '가격', '가공']
# 문서 79의 상위 키워드: ['경제', '개념', '듣기', '부담', '가게']
# 문서 80의 상위 키워드: ['강사', '국내', '유명', '강의', '가게']
# 문서 81의 상위 키워드: ['사용', '엄두', '막상', '띵커벨', '패들렛']
# 문서 82의 상위 키워드: ['운영', '위해', '우리', '보고', '고민']
# 문서 83의 상위 키워드: ['위기', '기후', '환경', '보존', '화두']
# 문서 84의 상위 키워드: ['수학', '기초', '포자', '단연', '제일']
# 문서 85의 상위 키워드: ['오히려', '가운데', '컴퓨터', '디지털', '경력']
# 문서 86의 상위 키워드: ['차마', '칱절히', '패들렛', '스스로', '정도']
# 문서 87의 상위 키워드: ['이탈리아', '여행', '강추추추', '로그인', '실상']
# 문서 88의 상위 키워드: ['신장', '형성', '학력', '관계', '기본']
# 문서 89의 상위 키워드: ['실습', '수강', '섣불리', '안배', '속도']
# 문서 90의 상위 키워드: ['기간', '동안', '직접', '다른', '강사']
# 문서 91의 상위 키워드: ['평화', '통일', '용기', '현장', '학교']
# 문서 92의 상위 키워드: ['내용', '활용', '수업', '가게', '가격']
# 문서 93의 상위 키워드: ['행동', '이해', '융통성', '믿음', '기반']
# 문서 94의 상위 키워드: ['버튼', '먹기', '정지', '원어민', '강좌']
# 문서 95의 상위 키워드: ['일상생활', '문법', '회화', '강사', '강의']
# 문서 96의 상위 키워드: ['아주', '기초', '제자리', '일주일', '걸음']
# 문서 97의 상위 키워드: ['토앻', '험담', '해도', '원어민', '현지']
# 문서 98의 상위 키워드: ['소프트웨어', '상세', '인공', '지능', '과정']
# 문서 99의 상위 키워드: ['변화', '당면', '주체', '핵심', '평가']
# 문서 100의 상위 키워드: ['워낙', '최태성', '수강', '선생님', '강의']
# 문서 101의 상위 키워드: ['모습', '미래', '학교', '연수', '가게']
# 문서 102의 상위 키워드: ['경영', '복습', '보고', '학급', '다시']
# 문서 103의 상위 키워드: ['강추', '실용', '아주', '사용', '정말']
# 문서 104의 상위 키워드: ['책자', '바램', '이해', '본기', '노력']
# 문서 105의 상위 키워드: ['김성남', '가르침', '통합교육', '실질', '교수']
# 문서 106의 상위 키워드: ['사이트', '아이스크림', '활용', '가게', '가격']
# 문서 107의 상위 키워드: ['공유', '디지털', '교육과정', '역량', '강조']
# 문서 108의 상위 키워드: ['한국어', '시험', '학급', '지도', '도움']
# 문서 109의 상위 키워드: ['마음', '탐구', '연결', '심리학', '대화']
# 문서 110의 상위 키워드: ['인공', '지능', '한계', '교육자', '발전']
# 문서 111의 상위 키워드: ['하교', '알짜', '부담', '추천', '아이']
# 문서 112의 상위 키워드: ['궁궐', '기행', '복원', '쏭내관', '건물']
# 문서 113의 상위 키워드: ['도파민', '분비', '현대인', '관련', '해결']
# 문서 114의 상위 키워드: ['금융', '활동', '정규', '보충', '교육']
# 문서 115의 상위 키워드: ['마을', '역할', '바탕', '전달', '정보']
# 문서 116의 상위 키워드: ['타로', '청강', '학생', '유지', '파악']
# 문서 117의 상위 키워드: ['보임', '도법', '중등', '초등', '향상']
# 문서 118의 상위 키워드: ['한자', '패턴', '도움', '가게', '가격']
# 문서 119의 상위 키워드: ['하나', '중국어', '초보자', '이해', '도움']
# 문서 120의 상위 키워드: ['인상', '중심', '현장', '교육', '가게']
# 문서 121의 상위 키워드: ['노션', '기초', '이해', '대해', '활용']
# 문서 122의 상위 키워드: ['노력', '교사', '인격', '거듭', '인식']
# 문서 123의 상위 키워드: ['발표', '아나운서', '태도', '강의', '참고']
# 문서 124의 상위 키워드: ['매일', '그림', '계기', '하나', '힐링']
# 문서 125의 상위 키워드: ['한글', '담임', '아주', '학년', '공부']
# 문서 126의 상위 키워드: ['내용', '연수', '가게', '가격', '가공']
# 문서 127의 상위 키워드: ['업무', '엑셀', '이용', '부담', '자신감']
# 문서 128의 상위 키워드: ['상처', '격려', '내면', '힐링', '신청']
# 문서 129의 상위 키워드: ['악기', '소리', '가게', '가격', '가공']
# 문서 130의 상위 키워드: ['콘텐츠', '실전', '기능', '제공', '아이스크림']
# 문서 131의 상위 키워드: ['실전', '사용', '연수', '가게', '가격']
# 문서 132의 상위 키워드: ['신규', '예시', '아이디어', '로서', '미래']
# 문서 133의 상위 키워드: ['세계', '나라', '여행', '여러', '생각']
# 문서 134의 상위 키워드: ['유일', '한글날', '세종대왕', '국어', '그동안']
# 문서 135의 상위 키워드: ['재테크', '공무원', '노후', '연금', '전혀']
# 문서 136의 상위 키워드: ['유네스코', '문화유산', '연수', '세계', '힐링']
# 문서 137의 상위 키워드: ['음성', '힐링', '보고', '추천', '생각']
# 문서 138의 상위 키워드: ['지나', '자주', '교수', '복습', '연수']
# 문서 139의 상위 키워드: ['여교사', '남자', '아이', '이해', '도움']
# 문서 140의 상위 키워드: ['마음', '혼자', '공감', '대화', '로서']
# 문서 141의 상위 키워드: ['전문가', '분야', '이야기', '생각', '가게']
# 문서 142의 상위 키워드: ['호르몬', '영향', '이해', '타인', '구입']
# 문서 143의 상위 키워드: ['인간', '강의', '사어', '원시', '유도']
# 문서 144의 상위 키워드: ['활용', '업무', '구글', '교사', '내용']
# 문서 145의 상위 키워드: ['레시피', '크게', '도움', '가게', '가격']
# 문서 146의 상위 키워드: ['시대', '변화', '연수', '가게', '가격']
# 문서 147의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 148의 상위 키워드: ['복습', '관찰', '예능', '중복', '행각']
# 문서 149의 상위 키워드: ['식물', '반려', '집사', '저런', '면서']
# 문서 150의 상위 키워드: ['여행', '언제', '다이고', '동반', '여기저기']
# 문서 151의 상위 키워드: ['밥상', '집밥', '아이디어', '강의', '도움']
# 문서 152의 상위 키워드: ['재정', '노하우', '공간', '참고', '진행']
# 문서 153의 상위 키워드: ['인성', '구체', '대해', '가게', '가격']
# 문서 154의 상위 키워드: ['조절', '감정', '방법', '대해', '가게']
# 문서 155의 상위 키워드: ['구글', '방법', '활용', '가게', '가격']
# 문서 156의 상위 키워드: ['중요성', '정리', '방법', '가게', '가격']
# 문서 157의 상위 키워드: ['중요성', '문해', '대해', '가게', '가격']
# 문서 158의 상위 키워드: ['상호작용', '개선', '행동', '문제', '방법']
# 문서 159의 상위 키워드: ['놀이', '활동', '도움', '가게', '가격']
# 문서 160의 상위 키워드: ['사람인', '베트남', '엄마', '우리', '아이']
# 문서 161의 상위 키워드: ['중요성', '강조', '안전', '가게', '가격']
# 문서 162의 상위 키워드: ['고민', '해곃준', '아이', '나영', '교수']
# 문서 163의 상위 키워드: ['매우', '지도', '학생', '이해', '도움']
# 문서 164의 상위 키워드: ['전반', '문해', '대해', '강의', '가게']
# 문서 165의 상위 키워드: ['학년', '도움', '가게', '가격', '가공']
# 문서 166의 상위 키워드: ['재료', '작품', '힐링', '연수', '가게']
# 문서 167의 상위 키워드: ['존중', '가족', '서로', '친구', '주변']
# 문서 168의 상위 키워드: ['중간', '영어', '듣기', '고대', '고루']
# 문서 169의 상위 키워드: ['폭력', '정당', '정당화', '방어', '공동체']
# 문서 170의 상위 키워드: ['정리', '구역', '생활화', '서랍', '연수']
# 문서 171의 상위 키워드: ['공동체', '가르침', '소프', '웨어', '하드웨어']
# 문서 172의 상위 키워드: ['시기', '모두', '이야기', '서일', '오신']
# 문서 173의 상위 키워드: ['꾸벅', '수학', '아이', '이해', '강의']
# 문서 174의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 175의 상위 키워드: ['엑셀', '조금', '본격', '함수', '만들기']
# 문서 176의 상위 키워드: ['연주', '계이름', '피아노', '전공', '코드']
# 문서 177의 상위 키워드: ['예문', '동안', '듣기', '반복', '다시']
# 문서 178의 상위 키워드: ['인간', '전문가', '행동', '역시', '과학']
# 문서 179의 상위 키워드: ['집중', '실천', '정리', '가게', '가격']
# 문서 180의 상위 키워드: ['기대', '이상', '내용', '연수', '가게']
# 문서 181의 상위 키워드: ['스타일', '공부', '가게', '가격', '가공']
# 문서 182의 상위 키워드: ['빵점', '자좀감', '지구', '연수', '나영']
# 문서 183의 상위 키워드: ['예제', '학교', '내용', '좀더', '엑셀']
# 문서 184의 상위 키워드: ['파워포인트', '한글', '엑셀', '대해', '연수']
# 문서 185의 상위 키워드: ['정성', '집밥', '모로', '준비', '아주']
# 문서 186의 상위 키워드: ['결과', '동식물', '멸종', '초래', '파괴']
# 문서 187의 상위 키워드: ['지구', '대응', '위기', '기후', '가게']
# 문서 188의 상위 키워드: ['대응', '적극', '상황', '가게', '가격']
# 문서 189의 상위 키워드: ['일부분', '이제야', '격려', '교재', '진행']
# 문서 190의 상위 키워드: ['동사', '하나', '자주', '통해', '활용']
# 문서 191의 상위 키워드: ['발음', '백배', '바로', '여행', '단어']
# 문서 192의 상위 키워드: ['교육', '무엇', '지향', '무언가', '요새']
# 문서 193의 상위 키워드: ['성장', '모두', '교사', '학생', '수업']
# 문서 194의 상위 키워드: ['위기', '기후', '역시', '수원', '대해']
# 문서 195의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 196의 상위 키워드: ['요리', '매사', '요리법', '한가지', '해먹']
# 문서 197의 상위 키워드: ['최고', '매우', '정리', '연수', '가게']
# 문서 198의 상위 키워드: ['법적', '풀이', '학폭', '소년법', '접근']
# 문서 199의 상위 키워드: ['조금', '내용', '가게', '가격', '가공']
# 문서 200의 상위 키워드: ['개괄', '실천', '기회', '방법', '교육']
# 문서 201의 상위 키워드: ['제목', '신청', '마음', '연수', '가게']
# 문서 202의 상위 키워드: ['패러다임', '심화', '공유', '흐름', '변화']
# 문서 203의 상위 키워드: ['여행', '유럽', '위해', '가게', '가격']
# 문서 204의 상위 키워드: ['사람', '변태', '호불호', '연습', '과제']
# 문서 205의 상위 키워드: ['설정', '진로', '방향', '고민', '교육']
# 문서 206의 상위 키워드: ['학년', '지도', '이해', '내용', '가게']
# 문서 207의 상위 키워드: ['의무', '예시', '연수로', '실제', '활용']
# 문서 208의 상위 키워드: ['시험', '가게', '가격', '가공', '가기']
# 문서 209의 상위 키워드: ['교육학', '내용', '가게', '가격', '가공']
# 문서 210의 상위 키워드: ['안전', '연수', '가게', '가격', '가공']
# 문서 211의 상위 키워드: ['기기', '스마트', '직접', '현장', '적용']
# 문서 212의 상위 키워드: ['자격증', '한국어', '더욱', '교사', '연수']
# 문서 213의 상위 키워드: ['시간', '활용', '수업', '연수', '가게']
# 문서 214의 상위 키워드: ['깨달', '육아', '한번', '다시', '교육']
# 문서 215의 상위 키워드: ['문해', '언어', '저학년', '우리', '기초']
# 문서 216의 상위 키워드: ['천재', '창작', '예술가', '인생', '작품']
# 문서 217의 상위 키워드: ['용기', '사람', '가게', '가격', '가공']
# 문서 218의 상위 키워드: ['상담', '교재', '학생', '도움', '연수']
# 문서 219의 상위 키워드: ['관심', '라가', '지혜', '내용', '집중']
# 문서 220의 상위 키워드: ['방문', '장소', '이탈리아', '연수', '여행']
# 문서 221의 상위 키워드: ['스페인어', '복습', '처음', '여러', '연수']
# 문서 222의 상위 키워드: ['저학년', '느낌', '다시', '영어', '가게']
# 문서 223의 상위 키워드: ['재테크', '주변', '처음', '추천', '선생님']
# 문서 224의 상위 키워드: ['그림', '작가', '심리', '흥미', '대해']
# 문서 225의 상위 키워드: ['부탁', '수업', '가게', '가격', '가공']
# 문서 226의 상위 키워드: ['배움', '과학', '교과', '과정', '준비']
# 문서 227의 상위 키워드: ['배움', '과학', '교과', '과정', '준비']
# 문서 228의 상위 키워드: ['다수', '근무', '다문화', '학교', '학생']
# 문서 229의 상위 키워드: ['이해도', '다문화', '학교', '대한', '아이']
# 문서 230의 상위 키워드: ['처음', '중요성', '계속', '준비', '기회']
# 문서 231의 상위 키워드: ['다문화', '관련', '단연', '방법', '전문성']
# 문서 232의 상위 키워드: ['편입', '내셔널', '그래픽', '소재', '다소']
# 문서 233의 상위 키워드: ['고등', '교원양성', '연수', '난이도', '만큼']
# 문서 234의 상위 키워드: ['초심', '기억', '계기', '과정', '다시']
# 문서 235의 상위 키워드: ['역사', '우리', '교욱', '부끄럼', '수립']
# 문서 236의 상위 키워드: ['의무', '이수', '시간', '가게', '가격']
# 문서 237의 상위 키워드: ['노래', '옛날', '음악', '힐링', '이야기']
# 문서 238의 상위 키워드: ['성적', '혹시', '시험', '다시', '생각']
# 문서 239의 상위 키워드: ['퍼스', '컬러', '가게', '가격', '가공']
# 문서 240의 상위 키워드: ['추천', '연수', '가게', '가격', '가공']
# 문서 241의 상위 키워드: ['오케스트라', '주심', '대한', '통해', '가게']
# 문서 242의 상위 키워드: ['그림책', '주기', '연결', '자연', '교육과정']
# 문서 243의 상위 키워드: ['문화유산', '그대로', '세계', '관광명소', '동이']
# 문서 244의 상위 키워드: ['문화유산', '그대로', '관광명소', '동이', '추억']
# 문서 245의 상위 키워드: ['교육', '서술', '평가', '신뢰', '객관']
# 문서 246의 상위 키워드: ['문제', '끄덕', '수도', '기도', '맞닥뜨릴']
# 문서 247의 상위 키워드: ['노션', '수강', '사용자', '구성', '개인']
# 문서 248의 상위 키워드: ['체육', '달인', '선생님', '정도', '간첩']
# 문서 249의 상위 키워드: ['부담', '학습', '내용', '가게', '가격']
# 문서 250의 상위 키워드: ['힐링', '연수', '시간', '가게', '가격']
# 문서 251의 상위 키워드: ['대비', '교육과정', '평가', '변화', '준비']
# 문서 252의 상위 키워드: ['금쪽', '반의', '잠깐', '담임', '로서']
# 문서 253의 상위 키워드: ['실생활', '표현', '사용', '가게', '가격']
# 문서 254의 상위 키워드: ['분야', '사회', '계기', '이야기', '강사']
# 문서 255의 상위 키워드: ['도마도', '반찬', '워킹', '레시피', '매일']
# 문서 256의 상위 키워드: ['기능', '구글', '사용', '활용', '처리']
# 문서 257의 상위 키워드: ['참고', '현장', '실제', '연수', '가게']
# 문서 258의 상위 키워드: ['외국', '보기', '나라', '한국', '경험']
# 문서 259의 상위 키워드: ['특별', '행동', '자주', '경우', '학생']
# 문서 260의 상위 키워드: ['안전', '연수', '가게', '가격', '가공']
# 문서 261의 상위 키워드: ['부분', '계해', '초등', '국어', '사회']
# 문서 262의 상위 키워드: ['블렌딩', '쓱쓱', '질감', '기쁨', '파스텔']
# 문서 263의 상위 키워드: ['맛있넹', '가게', '가격', '가공', '가기']
# 문서 264의 상위 키워드: ['조금', '금전', '무딘', '감각', '절약']
# 문서 265의 상위 키워드: ['영역', '사회', '초년', '아파트', '연금']
# 문서 266의 상위 키워드: ['중등', '약간', '거리', '초등', '수업']
# 문서 267의 상위 키워드: ['음악', '클래식', '해석', '우리', '설명']
# 문서 268의 상위 키워드: ['타로', '상세', '카드', '대해', '무척']
# 문서 269의 상위 키워드: ['기사', '뉴스', '나니', '영어', '연수']
# 문서 270의 상위 키워드: ['서도', '안전교육', '필수', '듣기', '시작']
# 문서 271의 상위 키워드: ['대답', '누군가', '정보', '정도', '평소']
# 문서 272의 상위 키워드: ['프로그램', '정착', '바램', '공교육', '도입']
# 문서 273의 상위 키워드: ['파친코', '텔러', '스토리', '보라', '단숨']
# 문서 274의 상위 키워드: ['준비물', '놀이', '며칠', '교감', '금방']
# 문서 275의 상위 키워드: ['학대', '범위', '분위기', '정서', '필요성']
# 문서 276의 상위 키워드: ['아이스크림', '모든', '제공', '매우', '사용']
# 문서 277의 상위 키워드: ['현장', '학교', '활용', '연수', '가게']
# 문서 278의 상위 키워드: ['동영상', '사진', '가게', '가격', '가공']
# 문서 279의 상위 키워드: ['전문가', '감정', '강의', '수업', '도움']
# 문서 280의 상위 키워드: ['업그레이드', '성교육', '기존', '자료', '수업']
# 문서 281의 상위 키워드: ['살림', '정리', '도움', '가게', '가격']
# 문서 282의 상위 키워드: ['의무감', '유행', '한번', '브루', '연수']
# 문서 283의 상위 키워드: ['커리큘럼', '감사', '부분', '가게', '가격']
# 문서 284의 상위 키워드: ['대화', '적요', '널리', '체감', '거나']
# 문서 285의 상위 키워드: ['기대', '미래', '이해', '도움', '가게']
# 문서 286의 상위 키워드: ['학력', '역량', '더욱', '우리', '기초']
# 문서 287의 상위 키워드: ['시작', '현아', '운영', '그림책', '사례']
# 문서 288의 상위 키워드: ['자의', '전환', '디지털', '역량', '시기']
# 문서 289의 상위 키워드: ['대해', '연수', '가게', '가격', '가공']
# 문서 290의 상위 키워드: ['궁금햇던', '감사', '평소', '연수', '가게']
# 문서 291의 상위 키워드: ['공존', '여실히', '탈바꿈', '방향성', '교육']
# 문서 292의 상위 키워드: ['소신', '이혜정', '장님', '교육', '대한']
# 문서 293의 상위 키워드: ['창체', '시간', '체육', '운영', '활동']
# 문서 294의 상위 키워드: ['듣기', '연수', '가게', '가격', '가공']
# 문서 295의 상위 키워드: ['소문', '어휘', '기본', '과정', '이해']
# 문서 296의 상위 키워드: ['학부모', '대처', '속마음', '순간', '확신']
# 문서 297의 상위 키워드: ['도움', '가게', '가격', '가공', '가기']
# 문서 298의 상위 키워드: ['교사', '교육', '대체', '아이', '궁금증']
# 문서 299의 상위 키워드: ['격려', '칭찬', '성장', '아이', '다짐']
# 문서 300의 상위 키워드: ['억양', '발음', '표현', '평소', '매우']
# 문서 301의 상위 키워드: ['통합', '중심', '문제', '사례', '학급']
# 문서 302의 상위 키워드: ['감사', '열강', '주심', '안내', '방향']
# 문서 303의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 304의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 305의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 306의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 307의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 308의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 309의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 310의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 311의 상위 키워드: ['세분', '역할', '인간', '행동', '과학']
# 문서 312의 상위 키워드: ['하나', '요구', '말씀', '변화', '반복']
# 문서 313의 상위 키워드: ['작가', '유명', '미술', '연수', '가게']
# 문서 314의 상위 키워드: ['태원', '휠링', '장소', '기쁨', '작가']
# 문서 315의 상위 키워드: ['입문', '유튜브', '전달', '사례', '추천']
# 문서 316의 상위 키워드: ['판서', '초등학교', '고학년', '전달', '한국사']
# 문서 317의 상위 키워드: ['감정', '표현', '자신', '강의', '마음']
# 문서 318의 상위 키워드: ['버스', '메타', '용어', '신청', '활용']
# 문서 319의 상위 키워드: ['교육', '오지', '인재', '공교육', '대한민국']
# 문서 320의 상위 키워드: ['마련', '통합', '친구', '운영', '자신감']
# 문서 321의 상위 키워드: ['적용', '번은', '드네', '이해', '동료']
# 문서 322의 상위 키워드: ['운영', '학급', '도움', '가게', '가격']
# 문서 323의 상위 키워드: ['수강', '설램', '씨즌', '쭉쭉', '가수']
# 문서 324의 상위 키워드: ['일본어', '어학', '등등', '일본', '문화']
# 문서 325의 상위 키워드: ['개월차', '연습장', '골프', '가면', '초보']
# 문서 326의 상위 키워드: ['시스템', '흐름', '가게', '가격', '가공']
# 문서 327의 상위 키워드: ['역할', '역량', '다문화', '사회', '교사']
# 문서 328의 상위 키워드: ['입장', '용어', '과학', '일상', '관련']
# 문서 329의 상위 키워드: ['감정', '실생활', '적용', '대해', '가게']
# 문서 330의 상위 키워드: ['감사', '정말', '내용', '도움', '연수']
# 문서 331의 상위 키워드: ['감사', '내용', '도움', '연수', '가게']
# 문서 332의 상위 키워드: ['감사', '내용', '도움', '연수', '가게']
# 문서 333의 상위 키워드: ['감사', '연수', '대해', '도움', '가게']
# 문서 334의 상위 키워드: ['로드', '아슁웠어', '테드', '자꾸', '서도']
# 문서 335의 상위 키워드: ['체계', '교실', '정리', '가게', '가격']
# 문서 336의 상위 키워드: ['세계', '여행', '구석', '유산', '연수']
# 문서 337의 상위 키워드: ['눈물', '당황', '살짝', '그림책', '이야기']
# 문서 338의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 339의 상위 키워드: ['집안', '정리', '가게', '가격', '가공']
# 문서 340의 상위 키워드: ['컬러', '정보', '느낌', '대한', '가게']
# 문서 341의 상위 키워드: ['다문화', '인구', '가야', '수가', '해나']
# 문서 342의 상위 키워드: ['노래', '느낌', '힐링', '시간', '강의']
# 문서 343의 상위 키워드: ['노력', '실천', '교육', '대해', '연수']
# 문서 344의 상위 키워드: ['원격', '지역', '연수', '강의', '설레임']
# 문서 345의 상위 키워드: ['도시', '다문화', '수강', '학생', '도움']
# 문서 346의 상위 키워드: ['거절', '자책', '사회생활', '성인', '여기']
# 문서 347의 상위 키워드: ['내면', '다시', '정말', '방법', '가게']
# 문서 348의 상위 키워드: ['쓰기', '말씀', '집중', '수강', '강사']
# 문서 349의 상위 키워드: ['교권', '권리', '진심', '요즘', '문제']
# 문서 350의 상위 키워드: ['평가', '작용', '기능', '과정', '능이']
# 문서 351의 상위 키워드: ['독서', '토론', '연수', '학생', '지도']
# 문서 352의 상위 키워드: ['조금', '이해', '가게', '가격', '가공']
# 문서 353의 상위 키워드: ['여행가', '가게', '가격', '가공', '가기']
# 문서 354의 상위 키워드: ['암기', '먼저', '표현', '가게', '가격']
# 문서 355의 상위 키워드: ['그것', '심리', '그림', '표현', '관련']
# 문서 356의 상위 키워드: ['취미', '연구', '자신', '힐링', '생활']
# 문서 357의 상위 키워드: ['오염', '가운데', '환경', '시대', '문제']
# 문서 358의 상위 키워드: ['자신', '모되', '텅빈', '인문학', '항상']
# 문서 359의 상위 키워드: ['인간관계', '이해', '심리', '아이', '도움']
# 문서 360의 상위 키워드: ['가기', '유럽', '미술', '작품', '직접']
# 문서 361의 상위 키워드: ['교재', '듣기', '문제', '노노', '주지']
# 문서 362의 상위 키워드: ['말로', '전문가', '무엇', '가게', '가격']
# 문서 363의 상위 키워드: ['무릎', '영상', '가게', '가격', '가공']
# 문서 364의 상위 키워드: ['기초', '증가', '출제', '보호', '교권']
# 문서 365의 상위 키워드: ['노션', '좀더', '강의', '사용', '입력']
# 문서 366의 상위 키워드: ['관리자', '수임', '개념', '로서', '기본']
# 문서 367의 상위 키워드: ['정리', '구석구석', '바르게', '집안', '방법']
# 문서 368의 상위 키워드: ['영어', '공부', '도움', '가게', '가격']
# 문서 369의 상위 키워드: ['영어', '공부', '도움', '가게', '가격']
# 문서 370의 상위 키워드: ['되엇습니', '영어', '공부', '도움', '가게']
# 문서 371의 상위 키워드: ['영어', '공부', '도움', '가게', '가격']
# 문서 372의 상위 키워드: ['영어', '공부', '가게', '가격', '가공']
# 문서 373의 상위 키워드: ['레크레이션', '도움', '가게', '가격', '가공']
# 문서 374의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 375의 상위 키워드: ['컴퓨터', '대해', '가게', '가격', '가공']
# 문서 376의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 377의 상위 키워드: ['아주', '부분', '대체로', '성벽', '성뼉']
# 문서 378의 상위 키워드: ['엮어가', '감정', '그림책', '수업', '가게']
# 문서 379의 상위 키워드: ['서양음악사', '마법', '일단', '전혀', '힐링']
# 문서 380의 상위 키워드: ['캐릭터', '설명', '연수', '가게', '가격']
# 문서 381의 상위 키워드: ['뚝딱', '미술', '학급', '연수', '가게']
# 문서 382의 상위 키워드: ['영어', '공부', '도움', '가게', '가격']
# 문서 383의 상위 키워드: ['컴퓨터', '핵심', '활용', '연수', '가게']
# 문서 384의 상위 키워드: ['영어', '공부', '도움', '가게', '가격']
# 문서 385의 상위 키워드: ['문화유산', '세계', '여행', '설명', '가게']
# 문서 386의 상위 키워드: ['힐링', '정말', '연수', '가게', '가격']
# 문서 387의 상위 키워드: ['작가', '이번', '몬드리안', '실화', '앤디']
# 문서 388의 상위 키워드: ['엑셀', '자신감', '평소', '가지', '대한']
# 문서 389의 상위 키워드: ['대체', '무엇', '추천', '가게', '가격']
# 문서 390의 상위 키워드: ['문장', '기본', '레벨', '드릴', '왕초보']
# 문서 391의 상위 키워드: ['근현대사', '흐름', '이야기', '연수', '가게']
# 문서 392의 상위 키워드: ['운동', '제약', '부족', '건강', '병행']
# 문서 393의 상위 키워드: ['최고', '연수', '가게', '가격', '가공']
# 문서 394의 상위 키워드: ['까치', '정호중', '파견', '감격', '살이']
# 문서 395의 상위 키워드: ['시민', '세계', '교육', '대해', '연수']
# 문서 396의 상위 키워드: ['한국사', '부담', '신청', '강의', '연수']
# 문서 397의 상위 키워드: ['점수', '한국사', '단점', '시험', '우리나라']
# 문서 398의 상위 키워드: ['화이팅', '성인', '어회', '오늘', '감사']
# 문서 399의 상위 키워드: ['항상', '감사', '연수', '가게', '가격']
# 문서 400의 상위 키워드: ['감사', '연수', '가게', '가격', '가공']
# 문서 401의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 402의 상위 키워드: ['활동', '격려', '이해', '이유', '먼저']
# 문서 403의 상위 키워드: ['사회생활', '교직', '평소', '생활', '도움']
# 문서 404의 상위 키워드: ['법률', '누구', '복습', '상황', '여러']
# 문서 405의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 406의 상위 키워드: ['포기', '이수', '이해', '가게', '가격']
# 문서 407의 상위 키워드: ['필수', '연수', '가게', '가격', '가공']
# 문서 408의 상위 키워드: ['위치', '현재', '시대', '사실', '변화']
# 문서 409의 상위 키워드: ['함양', '능력', '영어', '가게', '가격']
# 문서 410의 상위 키워드: ['의식', '함양', '안전', '정보', '가게']
# 문서 411의 상위 키워드: ['협력', '마을', '공동체', '사회', '더블']
# 문서 412의 상위 키워드: ['과정', '마음', '교육', '희망', '개설']
# 문서 413의 상위 키워드: ['교권', '요즘', '관련', '이야기', '매우']
# 문서 414의 상위 키워드: ['패러다임', '교육과정', '우리나라', '변화', '생각']
# 문서 415의 상위 키워드: ['법률', '실질', '일상', '제공', '정보']
# 문서 416의 상위 키워드: ['고민', '연수', '무색', '퀄리티', '정말']
# 문서 417의 상위 키워드: ['여행', '착각', '김용범', '편견', '해설']
# 문서 418의 상위 키워드: ['걱정', '통합', '처음', '이번', '통해']
# 문서 419의 상위 키워드: ['보고', '기도', '영상', '연수', '나래']
# 문서 420의 상위 키워드: ['욕심', '가도', '문화인', '뿜뿜', '스크립트']
# 문서 421의 상위 키워드: ['결과', '오늘', '학기', '시험', '현장']
# 문서 422의 상위 키워드: ['강의', '배속', '주요', '교안', '시스템']
# 문서 423의 상위 키워드: ['사용', '툴킷', '메뉴', '이름', '클래스']
# 문서 424의 상위 키워드: ['대순', '도슨', '투어', '순서', '미술관']
# 문서 425의 상위 키워드: ['보시', '노션', '개발자', '스타일', '초보']
# 문서 426의 상위 키워드: ['포맷', '차근차근', '정말', '가게', '가격']
# 문서 427의 상위 키워드: ['부분', '일도', '일상생활', '주변', '소개']
# 문서 428의 상위 키워드: ['하나로', '타로', '상담', '아이디어', '사용']
# 문서 429의 상위 키워드: ['간과', '영어', '순서', '실력', '향상']
# 문서 430의 상위 키워드: ['학생', '그림책', '수업', '성은', '어린이']
# 문서 431의 상위 키워드: ['통합', '해결', '상황', '학급', '교사']
# 문서 432의 상위 키워드: ['행동', '로서', '학생', '이해', '도대체']
# 문서 433의 상위 키워드: ['집중', '신념', '조이', '영어', '자칫']
# 문서 434의 상위 키워드: ['대하', '교권', '주변', '이번', '추천']
# 문서 435의 상위 키워드: ['이해', '유형', '낱낱이', '세분', '어른']
# 문서 436의 상위 키워드: ['방향', '변화', '미래', '교육', '대한']
# 문서 437의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 438의 상위 키워드: ['토익', '연상', '득점', '워드', '중요']
# 문서 439의 상위 키워드: ['자신감', '감히', '성의', '태도', '호기심']
# 문서 440의 상위 키워드: ['그림', '소재', '그릴', '아이', '파스텔']
# 문서 441의 상위 키워드: ['남자', '두고두고', '가득', '아이', '다짐']
# 문서 442의 상위 키워드: ['막상', '강의', '걱정', '이수', '여러']
# 문서 443의 상위 키워드: ['체육', '놀이', '바로', '아주', '교실']
# 문서 444의 상위 키워드: ['주신', '대처', '감사', '사례', '강사']
# 문서 445의 상위 키워드: ['개정', '사항', '이해', '교육과정', '전반']
# 문서 446의 상위 키워드: ['고전', '활동', '명작', '아이', '어휘']
# 문서 447의 상위 키워드: ['보고', '방안', '전문', '좀더', '초등']
# 문서 448의 상위 키워드: ['시시비비', '동의', '보호', '현실', '교권']
# 문서 449의 상위 키워드: ['계속', '복습', '정도', '연수', '가게']
# 문서 450의 상위 키워드: ['부진', '학습', '학생', '학교', '개인']
# 문서 451의 상위 키워드: ['그림책', '수업', '거기', '재미', '저학년']
# 문서 452의 상위 키워드: ['교권', '사안', '교사', '로서', '생각']
# 문서 453의 상위 키워드: ['나라', '별로', '거주', '물가', '치안']
# 문서 454의 상위 키워드: ['초등', '수준', '참고', '학기', '교과']
# 문서 455의 상위 키워드: ['과학', '원리', '지도', '교과', '초등']
# 문서 456의 상위 키워드: ['내면', '마음', '계기', '고자', '지도']
# 문서 457의 상위 키워드: ['기록', '노트', '공부', '가게', '가격']
# 문서 458의 상위 키워드: ['시생', '대학', '책임', '교원', '한글']
# 문서 459의 상위 키워드: ['고로', '차도', '파파', '영어', '실시간']
# 문서 460의 상위 키워드: ['호기심', '영어', '생각', '가게', '가격']
# 문서 461의 상위 키워드: ['파이썬', '코드', '매번', '대해', '강의']
# 문서 462의 상위 키워드: ['의무', '이수', '내용', '연수', '가게']
# 문서 463의 상위 키워드: ['전세계', '비중', '구조', '추가', '안내']
# 문서 464의 상위 키워드: ['처음', '일쑤', '지금껏', '분량', '의욕']
# 문서 465의 상위 키워드: ['부동산', '금융', '상품', '위치', '교사']
# 문서 466의 상위 키워드: ['절로', '구입', '배움', '놀이', '선생님']
# 문서 467의 상위 키워드: ['모든', '열풍', '전국', '이혜정', '장님']
# 문서 468의 상위 키워드: ['믿음', '상식', '인공', '전문가', '지능']
# 문서 469의 상위 키워드: ['인사이트', '집중', '강사', '가게', '가격']
# 문서 470의 상위 키워드: ['위해', '수일', '코칭', '아이', '뭔가']
# 문서 471의 상위 키워드: ['일상생활', '학교', '교육', '도움', '연수']
# 문서 472의 상위 키워드: ['일상생활', '학교', '내용', '도움', '연수']
# 문서 473의 상위 키워드: ['심리', '요인', '학생', '자연', '여러가지']
# 문서 474의 상위 키워드: ['심리', '여러가지', '학생', '놀이', '교시']
# 문서 475의 상위 키워드: ['원어민', '효과', '일상', '표현', '실제']
# 문서 476의 상위 키워드: ['끈기', '실력', '주시', '노력', '영어']
# 문서 477의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 478의 상위 키워드: ['적용', '강의', '연수', '가게', '가격']
# 문서 479의 상위 키워드: ['평소', '이번', '관심', '교육', '통해']
# 문서 480의 상위 키워드: ['띵커벨', '패들렛', '현장', '연수', '활용']
# 문서 481의 상위 키워드: ['옆반', '도입', '체계', '패들렛', '아주']
# 문서 482의 상위 키워드: ['걱정', '안전', '생활', '연수', '아이']
# 문서 483의 상위 키워드: ['설문지', '가끔', '발전', '시도', '코로나']
# 문서 484의 상위 키워드: ['실생활', '정말', '추천', '도움', '연수']
# 문서 485의 상위 키워드: ['망라', '상징물', '건축물', '진작', '도시']
# 문서 486의 상위 키워드: ['정보', '네이버', '복제', '수첩', '차곡차곡']
# 문서 487의 상위 키워드: ['교단', '서기', '제자', '최선', '교사']
# 문서 488의 상위 키워드: ['대화', '문장', '듣기', '내용', '단어']
# 문서 489의 상위 키워드: ['전문가', '차근차근', '느낌', '가게', '가격']
# 문서 490의 상위 키워드: ['경제', '이제', '생활', '관념', '기만']
# 문서 491의 상위 키워드: ['마무리', '미리보기', '예정', '대충', '노트']
# 문서 492의 상위 키워드: ['상황', '펜데믹', '적응', '무기', '탈출']
# 문서 493의 상위 키워드: ['목표', '살기', '하루하루', '가게', '가격']
# 문서 494의 상위 키워드: ['전문', '매우', '내용', '강의', '가게']
# 문서 495의 상위 키워드: ['기회', '강사', '강의', '가게', '가격']
# 문서 496의 상위 키워드: ['포인트', '접근', '쏙쏙', '무엇', '학급']
# 문서 497의 상위 키워드: ['게임', '참여', '보드', '규칙', '설명']
# 문서 498의 상위 키워드: ['활용', '가게', '가격', '가공', '가기']
# 문서 499의 상위 키워드: ['그림책', '수업', '열의', '진정', '기술']
# 문서 500의 상위 키워드: ['해소', '스트레스', '마음', '연수', '가게']
# 문서 501의 상위 키워드: ['역량', '에듀', '테크', '자료', '학생']
# 문서 502의 상위 키워드: ['문제', '예외', '영어문법', '살짝', '연습']
# 문서 503의 상위 키워드: ['장단점', '미리', '에듀', '테크', '도구']
# 문서 504의 상위 키워드: ['정말', '강의', '가게', '가격', '가공']
# 문서 505의 상위 키워드: ['학습', '의의', '단순', '차원', '성찰']
# 문서 506의 상위 키워드: ['과감', '렵니', '비교', '인상', '시도']
# 문서 507의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 508의 상위 키워드: ['티브', '평상시', '아쉬움', '역사', '관심']
# 문서 509의 상위 키워드: ['스트레칭', '퇴근', '마무리', '하니', '요가']
# 문서 510의 상위 키워드: ['담당', '교직원', '무엇', '관심', '설명']
# 문서 511의 상위 키워드: ['운동', '되엇습니', '동작', '필요성', '더욱']
# 문서 512의 상위 키워드: ['국내', '대한', '체계', '사례', '현장']
# 문서 513의 상위 키워드: ['중국어', '패턴', '항상', '문법', '아주']
# 문서 514의 상위 키워드: ['항상', '체육', '소개', '활동', '고민']
# 문서 515의 상위 키워드: ['수확', '연기자', '열연', '프롤로그', '학교']
# 문서 516의 상위 키워드: ['선구자', '회피', '이혜정', '장님', '발전']
# 문서 517의 상위 키워드: ['저학년', '반론', '받아쓰기', '수표', '내일']
# 문서 518의 상위 키워드: ['말문', '행시', '두려움', '쏙쏙', '자신감']
# 문서 519의 상위 키워드: ['숙고', '주소', '교육', '학생', '실행']
# 문서 520의 상위 키워드: ['실제', '적용', '활용', '내용', '강의']
# 문서 521의 상위 키워드: ['엔트리', '이해도', '방법', '활용', '수업']
# 문서 522의 상위 키워드: ['관점', '관계', '여러', '가지', '방법']
# 문서 523의 상위 키워드: ['그림책', '다방면', '예시', '운영', '학급']
# 문서 524의 상위 키워드: ['경영', '설명', '영상', '학급', '감수']
# 문서 525의 상위 키워드: ['기후', '환경', '토크쇼', '체감', '교육']
# 문서 526의 상위 키워드: ['시연', '하니', '실제', '이해', '가게']
# 문서 527의 상위 키워드: ['해외', '학교', '근무', '여러', '생활']
# 문서 528의 상위 키워드: ['안전', '사고', '각종', '재난', '교사']
# 문서 529의 상위 키워드: ['수업', '준비', '덩달아', '상승', '기법']
# 문서 530의 상위 키워드: ['나이', '시작', '다가', '미적', '세라']
# 문서 531의 상위 키워드: ['여행', '예정', '복습', '수강', '준비']
# 문서 532의 상위 키워드: ['안전', '교육', '전문', '교직', '별로']
# 문서 533의 상위 키워드: ['다문화', '교육', '가게', '가격', '가공']
# 문서 534의 상위 키워드: ['우리', '한국어', '모국어', '취득', '국력']
# 문서 535의 상위 키워드: ['독후', '고전', '한번', '활동', '신청']
# 문서 536의 상위 키워드: ['기분', '힐링', '정리', '가게', '가격']
# 문서 537의 상위 키워드: ['초등학교', '담임', '저학년', '그림책', '활용']
# 문서 538의 상위 키워드: ['고도원', '인생', '연구', '올해', '도전']
# 문서 539의 상위 키워드: ['나라', '이탈리아', '문화유산', '전체', '세계']
# 문서 540의 상위 키워드: ['내외', '대처', '사고', '안전', '학교']
# 문서 541의 상위 키워드: ['부진', '개념', '직접', '학습', '지도']
# 문서 542의 상위 키워드: ['여름', '아들', '유럽', '내내', '힐링']
# 문서 543의 상위 키워드: ['소설', '파친코', '텔러', '자꾸', '스토리']
# 문서 544의 상위 키워드: ['발자국', '가게', '자격증', '한국어', '교사']
# 문서 545의 상위 키워드: ['해당', '인공', '지능', '통해', '대해']
# 문서 546의 상위 키워드: ['파이썬', '스쿨', '엔트리', '코딩', '중학교']
# 문서 547의 상위 키워드: ['관상학', '매력', '호기심', '연수', '가게']
# 문서 548의 상위 키워드: ['기특', '수해', '때론', '병행', '수업']
# 문서 549의 상위 키워드: ['된거', '강추', '실질', '다문화', '학교']
# 문서 550의 상위 키워드: ['대화', '직원', '한결', '작용', '기술']
# 문서 551의 상위 키워드: ['대화', '직원', '한결', '작용', '기술']
# 문서 552의 상위 키워드: ['처리', '공간', '일상', '반복', '정리']
# 문서 553의 상위 키워드: ['양식', '한문', '만점', '모로', '활용']
# 문서 554의 상위 키워드: ['길라잡이', '안전교육', '안전', '학교', '학생']
# 문서 555의 상위 키워드: ['난독증', '경계', '문해', '지도', '학생']
# 문서 556의 상위 키워드: ['띵커벨', '에듀', '테크', '패들렛', '도구']
# 문서 557의 상위 키워드: ['도구', '바로', '실제', '적용', '수업']
# 문서 558의 상위 키워드: ['작곡', '클랙식', '악기', '클래식', '특징']
# 문서 559의 상위 키워드: ['단체', '시민', '역할', '세계', '기본']
# 문서 560의 상위 키워드: ['전수', '정리정돈', '편이', '꿀팁', '평소']
# 문서 561의 상위 키워드: ['업데이트', '반영', '사항', '최신', '수정']
# 문서 562의 상위 키워드: ['노션', '내용', '무척', '것임', '수록']
# 문서 563의 상위 키워드: ['부자', '무척', '자체', '용어', '경제']
# 문서 564의 상위 키워드: ['영어', '교양', '듭니', '흥미', '부담']
# 문서 565의 상위 키워드: ['노션', '갱년기', '머릿', '얼마', '마무리']
# 문서 566의 상위 키워드: ['만화', '인간', '심리', '재미', '설명']
# 문서 567의 상위 키워드: ['중심', '사례', '가게', '가격', '가공']
# 문서 568의 상위 키워드: ['보기', '재테크', '실천', '계기', '생각']
# 문서 569의 상위 키워드: ['나영', '교수', '신청', '연수', '가게']
# 문서 570의 상위 키워드: ['글씨체', '글씨', '연수', '자신감', '평소']
# 문서 571의 상위 키워드: ['법률', '계몽', '관련성', '맞춤화', '소화']
# 문서 572의 상위 키워드: ['안전', '학점', '안전교육', '수원', '이수']
# 문서 573의 상위 키워드: ['격차', '이후', '코로나', '고민', '학습']
# 문서 574의 상위 키워드: ['친밀', '내적', '소리', '형성', '격려']
# 문서 575의 상위 키워드: ['공간', '정리', '방법', '통해', '연수']
# 문서 576의 상위 키워드: ['정재승', '자체', '전달', '교수', '설명']
# 문서 577의 상위 키워드: ['침해', '교권', '징계', '처신', '품위']
# 문서 578의 상위 키워드: ['공유', '주시', '자료', '현장', '사용']
# 문서 579의 상위 키워드: ['콘텐츠', '용법', '선생님', '이해', '대해']
# 문서 580의 상위 키워드: ['동기유발', '웹툰', '소리', '일상생활', '흥미']
# 문서 581의 상위 키워드: ['다양성', '통한', '참여', '그림책', '방법']
# 문서 582의 상위 키워드: ['학력', '한글', '어려움', '현장', '기초']
# 문서 583의 상위 키워드: ['능률', '퇴근', '휴식', '공간', '힐링']
# 문서 584의 상위 키워드: ['패러다임', '만큼', '평가', '주변', '모두']
# 문서 585의 상위 키워드: ['지현', '형성', '감정', '관계', '강의']
# 문서 586의 상위 키워드: ['손가락', '연주가', '도전', '연수', '가게']
# 문서 587의 상위 키워드: ['진행자', '토크', '가게', '가격', '가공']
# 문서 588의 상위 키워드: ['사람', '정신과', '도움', '지금', '추천']
# 문서 589의 상위 키워드: ['책임', '대해', '시민', '행동', '세계']
# 문서 590의 상위 키워드: ['노출', '대중음악', '클래식', '구성', '우리']
# 문서 591의 상위 키워드: ['성격', '유형', '가족', '동료', '통해']
# 문서 592의 상위 키워드: ['관해', '정말', '가게', '가격', '가공']
# 문서 593의 상위 키워드: ['두려움', '미국', '예시', '대화', '표현']
# 문서 594의 상위 키워드: ['현지', '미국', '대화', '복습', '실제']
# 문서 595의 상위 키워드: ['필요성', '전반', '대하', '의미', '무엇']
# 문서 596의 상위 키워드: ['온라인', '개념', '수업', '여파', '메이커']
# 문서 597의 상위 키워드: ['제법', '스마트', '연수', '가게', '가격']
# 문서 598의 상위 키워드: ['정착', '교육', '요소', '패러다임', '파악']
# 문서 599의 상위 키워드: ['마을', '교육', '아이', '공생', '영주']
# 문서 600의 상위 키워드: ['폭력', '예방', '모든', '생시', '약자']
# 문서 601의 상위 키워드: ['마을', '교육', '구성원', '간다', '체험']
# 문서 602의 상위 키워드: ['문화', '세계', '생활양식', '절호', '곳곳']
# 문서 603의 상위 키워드: ['최신', '우선', '내용', '컴퓨터', '현재']
# 문서 604의 상위 키워드: ['배움', '수업', '가게', '가격', '가공']
# 문서 605의 상위 키워드: ['전개', '사건', '배경', '예시', '별로']
# 문서 606의 상위 키워드: ['감정', '공감', '관계', '위해', '방법']
# 문서 607의 상위 키워드: ['문법', '한국어', '부분', '사용', '교육']
# 문서 608의 상위 키워드: ['교통사고', '보험', '부동산', '바램', '법률']
# 문서 609의 상위 키워드: ['문해', '발달', '전문성', '향상', '환경']
# 문서 610의 상위 키워드: ['발상', '교육', '위해', '지도', '아이']
# 문서 611의 상위 키워드: ['몰입', '전반', '흐름', '진행', '강사']
# 문서 612의 상위 키워드: ['홀용', '주제', '연습', '구성', '아주']
# 문서 613의 상위 키워드: ['시간', '가게', '가격', '가공', '가기']
# 문서 614의 상위 키워드: ['매우', '정리', '가게', '가격', '가공']
# 문서 615의 상위 키워드: ['특색', '사업', '위기', '기후', '습득']
# 문서 616의 상위 키워드: ['영상', '관련', '영어', '공부', '가게']
# 문서 617의 상위 키워드: ['의사', '진단', '상태', '작가', '흥미']
# 문서 618의 상위 키워드: ['정말', '종종', '아침', '시간', '영상']
# 문서 619의 상위 키워드: ['깊이', '문해', '현장', '고민', '아이']
# 문서 620의 상위 키워드: ['당황', '편이', '후회', '막상', '시도']
# 문서 621의 상위 키워드: ['적응', '실전', '안내', '현재', '제시']
# 문서 622의 상위 키워드: ['공감', '연수', '가게', '가격', '가공']
# 문서 623의 상위 키워드: ['스토리', '다만', '회화', '집중', '상황']
# 문서 624의 상위 키워드: ['빈번', '침해', '라면', '실생활', '필수']
# 문서 625의 상위 키워드: ['학인', '모국어', '한국어', '계기', '부분']
# 문서 626의 상위 키워드: ['현장', '활용', '가게', '가격', '가공']
# 문서 627의 상위 키워드: ['엑기스', '살기', '미국', '일상생활', '대화']
# 문서 628의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 629의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 630의 상위 키워드: ['경기도', '치가', '한셀', '퇴근', '교육청']
# 문서 631의 상위 키워드: ['유명인', '얼굴', '통한', '그림', '사례']
# 문서 632의 상위 키워드: ['특수', '거의', '지금', '우리', '학급']
# 문서 633의 상위 키워드: ['얼른', '교실', '가게', '가격', '가공']
# 문서 634의 상위 키워드: ['경향', '특징', '관해', '유형', '소통']
# 문서 635의 상위 키워드: ['사랑', '힐링', '방법', '시간', '가게']
# 문서 636의 상위 키워드: ['안전', '학교', '가게', '가격', '가공']
# 문서 637의 상위 키워드: ['중심', '쏙쏙', '연수', '제공', '더욱']
# 문서 638의 상위 키워드: ['교육제도', '입시', '하루', '실천', '교실']
# 문서 639의 상위 키워드: ['참여', '모델링', '학교', '그린', '시행']
# 문서 640의 상위 키워드: ['명사', '대거', '욕심', '강의', '정도']
# 문서 641의 상위 키워드: ['누구', '어려움', '로서', '한번', '교사']
# 문서 642의 상위 키워드: ['중요', '진짜', '언어', '처음', '기초']
# 문서 643의 상위 키워드: ['최고', '지금', '아이스크림', '강의', '가게']
# 문서 644의 상위 키워드: ['챗봇', '수도', '중간', '수업', '주제']
# 문서 645의 상위 키워드: ['우리말', '살피', '의문', '주기', '습득']
# 문서 646의 상위 키워드: ['사용', '의문', '저절로', '우리말', '외국인']
# 문서 647의 상위 키워드: ['여행', '영어', '말문', '외국', '선생님']
# 문서 648의 상위 키워드: ['수업', '사용', '중인', '몇몇', '흥미진진']
# 문서 649의 상위 키워드: ['수진', '신뢰', '자리', '직업', '이후']
# 문서 650의 상위 키워드: ['그림', '소개', '요즈음', '인기', '치유']
# 문서 651의 상위 키워드: ['무척', '저학년', '도움', '그림책', '평소']
# 문서 652의 상위 키워드: ['유릭', '특수교육', '역할', '대상', '통합']
# 문서 653의 상위 키워드: ['기기', '스마트', '교실', '활용', '도움']
# 문서 654의 상위 키워드: ['오류', '발견', '습관', '인간', '평소']
# 문서 655의 상위 키워드: ['그림책', '우선', '활용', '수업', '적용']
# 문서 656의 상위 키워드: ['해나', '경력', '그림', '운영', '학급']
# 문서 657의 상위 키워드: ['토익', '공부', '설명', '선생님', '내용']
# 문서 658의 상위 키워드: ['교육과정', '과학', '단원', '발전', '계획']
# 문서 659의 상위 키워드: ['노트북', '만족도', '잡고', '활용', '완성']
# 문서 660의 상위 키워드: ['법지', '설명', '선생님', '가게', '가격']
# 문서 661의 상위 키워드: ['과정', '영어', '자료', '왕초보', '통해']
# 문서 662의 상위 키워드: ['건가', '학교', '교사', '아이', '서서히']
# 문서 663의 상위 키워드: ['말씀', '프로그램', '편성', '사용', '한결']
# 문서 664의 상위 키워드: ['생활', '학교', '도움', '연수', '가게']
# 문서 665의 상위 키워드: ['과학', '무심코', '실험', '발견', '이론']
# 문서 666의 상위 키워드: ['일상', '생활', '지도', '연수', '아이']
# 문서 667의 상위 키워드: ['판례', '중심', '교권', '관련', '현장']
# 문서 668의 상위 키워드: ['들어얗', '족금', '억지로', '수학', '노력']
# 문서 669의 상위 키워드: ['었습', '간접', '후회', '경험', '시험']
# 문서 670의 상위 키워드: ['와인', '마트', '탈출', '상식', '수준']
# 문서 671의 상위 키워드: ['환경', '교육', '수업', '제시', '실천']
# 문서 672의 상위 키워드: ['창덕궁', '궁궐', '오프라인', '현재', '온라인']
# 문서 673의 상위 키워드: ['안전', '대책', '요령', '신영일', '얻지']
# 문서 674의 상위 키워드: ['통합교육', '연수', '예체능', '전하', '관계자']
# 문서 675의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 676의 상위 키워드: ['법률', '연수로', '지식', '가게', '가격']
# 문서 677의 상위 키워드: ['노션', '실습', '경우', '차근차근', '별로']
# 문서 678의 상위 키워드: ['해버렵니', '위안', '마음가짐', '실행', '이제']
# 문서 679의 상위 키워드: ['전담', '영어', '연수', '표현', '주욱']
# 문서 680의 상위 키워드: ['그림', '구경', '비교', '서도', '화가']
# 문서 681의 상위 키워드: ['신청', '봄날', '미술관', '선물', '목소리']
# 문서 682의 상위 키워드: ['민화', '화기', '색감', '기법', '사진']
# 문서 683의 상위 키워드: ['별것', '연수', '가게', '가격', '가공']
# 문서 684의 상위 키워드: ['기인', '주지', '혁신', '자발', '원인']
# 문서 685의 상위 키워드: ['나가야', '방식', '한국', '고민', '시간']
# 문서 686의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 687의 상위 키워드: ['추진', '교육청', '최근', '정보', '여러']
# 문서 688의 상위 키워드: ['그레이', '콘텐츠', '제작', '계속', '연수']
# 문서 689의 상위 키워드: ['안전교육', '연수', '가게', '가격', '가공']
# 문서 690의 상위 키워드: ['에듀', '테크', '사이트', '프로그램', '자부']
# 문서 691의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 692의 상위 키워드: ['칼림바', '연주', '지도', '학생', '도움']
# 문서 693의 상위 키워드: ['평가', '듣기', '느낌', '문제', '조금']
# 문서 694의 상위 키워드: ['생활', '실제', '영어', '추천', '가게']
# 문서 695의 상위 키워드: ['잠깐', '체육', '아이', '시간', '활용']
# 문서 696의 상위 키워드: ['관계', '또래', '형성', '학기', '운영']
# 문서 697의 상위 키워드: ['이해', '사람', '다른', '매우', '학생']
# 문서 698의 상위 키워드: ['무량', '업무', '연수', '강의', '도움']
# 문서 699의 상위 키워드: ['강의', '수강', '매우', '강사', '연수']
# 문서 700의 상위 키워드: ['수고', '가게', '가격', '가공', '가기']
# 문서 701의 상위 키워드: ['튜브', '하이', '혁명', '툴킷', '클래스']
# 문서 702의 상위 키워드: ['사건', '근현대사', '한국', '역사', '정리']
# 문서 703의 상위 키워드: ['식물', '도전', '교실', '가게', '가격']
# 문서 704의 상위 키워드: ['드로잉', '라인', '색연필', '수채화', '동아리활동']
# 문서 705의 상위 키워드: ['완성', '상권', '새삼', '활용', '강추']
# 문서 706의 상위 키워드: ['필요', '감정', '바로', '상황', '도움']
# 문서 707의 상위 키워드: ['제주도', '미처', '상식', '참고', '여러가지']
# 문서 708의 상위 키워드: ['산다', '이제', '내용', '생각', '도움']
# 문서 709의 상위 키워드: ['조언', '음료', '카페', '여유', '만들기']
# 문서 710의 상위 키워드: ['군더더기', '구성', '내용', '연수', '가게']
# 문서 711의 상위 키워드: ['중국어', '강좌', '다음', '연수로', '기초']
# 문서 712의 상위 키워드: ['보고', '고전', '의미', '활동', '이야기']
# 문서 713의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 714의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 715의 상위 키워드: ['변화', '교육', '연수', '가게', '가격']
# 문서 716의 상위 키워드: ['교육활동', '가정', '다문화', '지도', '방법']
# 문서 717의 상위 키워드: ['학급', '활용', '가게', '가격', '가공']
# 문서 718의 상위 키워드: ['유튜브', '교육', '활용', '가게', '가격']
# 문서 719의 상위 키워드: ['중간', '내용', '하진', '설명', '고등학교']
# 문서 720의 상위 키워드: ['사진', '어디', '사랑', '나레이션', '어찌']
# 문서 721의 상위 키워드: ['수업', '정답', '수학', '더욱', '문구']
# 문서 722의 상위 키워드: ['와인', '연수', '대해', '생각', '가게']
# 문서 723의 상위 키워드: ['해외여행', '쏙쏙', '구성', '내용', '강의']
# 문서 724의 상위 키워드: ['공예', '리본', '지인', '선물', '직접']
# 문서 725의 상위 키워드: ['기계공학', '외과', '외과의사', '재활', '헌신']
# 문서 726의 상위 키워드: ['안전교육', '모두', '학교', '가게', '가격']
# 문서 727의 상위 키워드: ['취미', '여유', '주제', '시간', '연수']
# 문서 728의 상위 키워드: ['수업', '목록', '힐링', '정리', '적용']
# 문서 729의 상위 키워드: ['진도', '에듀', '테크', '업무', '버거운']
# 문서 730의 상위 키워드: ['이어도', '정리', '뭔가', '경력', '동료']
# 문서 731의 상위 키워드: ['거려', '음질', '이현정', '질적', '본래']
# 문서 732의 상위 키워드: ['해답', '뭔가', '요즘', '조금', '아이']
# 문서 733의 상위 키워드: ['개념', '기초', '조금', '학습', '대해']
# 문서 734의 상위 키워드: ['보고', '가게', '가격', '가공', '가기']
# 문서 735의 상위 키워드: ['교육', '어디', '체계', '미래', '무엇']
# 문서 736의 상위 키워드: ['답변', '활용', '가짜', '구별', '그름']
# 문서 737의 상위 키워드: ['청소년기', '아이', '발병', '자살률', '질병']
# 문서 738의 상위 키워드: ['내분비학', '분비', '이해해', '의학', '유명']
# 문서 739의 상위 키워드: ['감정', '아이디어', '그림책', '여러', '통해']
# 문서 740의 상위 키워드: ['이해', '대해', '인간', '가지', '적용']
# 문서 741의 상위 키워드: ['독서', '글쓰기', '독후', '학생', '토론']
# 문서 742의 상위 키워드: ['가성', '실속', '프로그램', '바로', '적용']
# 문서 743의 상위 키워드: ['미국', '볼거리', '나라', '연수로', '정도']
# 문서 744의 상위 키워드: ['즉시', '현장', '활용', '도움', '가게']
# 문서 745의 상위 키워드: ['보호', '교권', '학습', '가게', '가격']
# 문서 746의 상위 키워드: ['타일러', '끝장', '한국인', '외국인', '실용']
# 문서 747의 상위 키워드: ['일방', '설정', '위주', '환경', '모습']
# 문서 748의 상위 키워드: ['반복', '전공자', '고고', '국어교육', '이해']
# 문서 749의 상위 키워드: ['김밥', '메밀', '애슐리', '코너', '퀸즈']
# 문서 750의 상위 키워드: ['체육관', '수임', '이용', '소개', '놀이']
# 문서 751의 상위 키워드: ['절감', '피상', '실상', '생태', '전환']
# 문서 752의 상위 키워드: ['교구', '수임', '실용', '구입', '체육']
# 문서 753의 상위 키워드: ['유초등', '초점', '저학년', '학년', '적용']
# 문서 754의 상위 키워드: ['선호', '원격', '특성', '대비', '자격증']
# 문서 755의 상위 키워드: ['구년', '제로', '안목', '성격', '유형']
# 문서 756의 상위 키워드: ['교양', '고전', '학생', '대해', '연수']
# 문서 757의 상위 키워드: ['토익', '공부', '강의', '가게', '가격']
# 문서 758의 상위 키워드: ['똑똑', '모자라', '안개', '탐험대', '얼마']
# 문서 759의 상위 키워드: ['수업', '하나', '재미', '진도', '활동']
# 문서 760의 상위 키워드: ['추천', '연수', '사용', '하나', '띵커벨']
# 문서 761의 상위 키워드: ['에듀', '테크', '덕분', '조금', '대해']
# 문서 762의 상위 키워드: ['공간', '가게', '가격', '가공', '가기']
# 문서 763의 상위 키워드: ['정리', '수납', '물건', '아이', '여러가지']
# 문서 764의 상위 키워드: ['미술관', '여러', '가게', '가격', '가공']
# 문서 765의 상위 키워드: ['고등학생', '적극', '참여', '조금', '방법']
# 문서 766의 상위 키워드: ['완료', '나니', '숙제', '마치', '여기']
# 문서 767의 상위 키워드: ['접근', '부분', '체감', '중학교', '근무']
# 문서 768의 상위 키워드: ['만화', '이해도', '심리학', '실질', '실생활']
# 문서 769의 상위 키워드: ['기기', '스마트', '좀더', '준비', '활용']
# 문서 770의 상위 키워드: ['폭력', '학교', '예방', '대처', '방법']
# 문서 771의 상위 키워드: ['배려', '상대방', '존중', '형성', '긍정']
# 문서 772의 상위 키워드: ['대출', '초년', '저축', '절약', '아파트']
# 문서 773의 상위 키워드: ['안식', '힐링', '마음', '추천', '연수']
# 문서 774의 상위 키워드: ['운영', '시작', '이야기', '학급', '적용']
# 문서 775의 상위 키워드: ['꼬리', '교권', '감사', '이야기', '가게']
# 문서 776의 상위 키워드: ['수업', '그림', '자료', '현장', '적용']
# 문서 777의 상위 키워드: ['이해력', '경제', '구체', '개념', '기본']
# 문서 778의 상위 키워드: ['정보', '실험', '대체', '준비', '대한']
# 문서 779의 상위 키워드: ['시간', '교권', '개념', '사례', '대한']
# 문서 780의 상위 키워드: ['아주', '시간', '가게', '가격', '가공']
# 문서 781의 상위 키워드: ['퇴직', '대상', '경제', '다음', '교사']
# 문서 782의 상위 키워드: ['고요함', '저녁', '편안함', '내일', '시간']
# 문서 783의 상위 키워드: ['도달', '다방면', '아동', '사이트', '부진']
# 문서 784의 상위 키워드: ['수진', '아이', '학급', '감명', '매너리즘']
# 문서 785의 상위 키워드: ['하니', '차근차근', '기본', '설명', '도움']
# 문서 786의 상위 키워드: ['내용', '핵심', '구성', '연수', '가게']
# 문서 787의 상위 키워드: ['자세', '중요', '교육', '항상', '연구']
# 문서 788의 상위 키워드: ['그림', '자신감', '리다', '대한', '두려움']
# 문서 789의 상위 키워드: ['역량', '참여', '자신', '연수', '가게']
# 문서 790의 상위 키워드: ['단어', '영어', '번역', '턱턱', '말문']
# 문서 791의 상위 키워드: ['표현', '연습', '청취', '실제', '배우']
# 문서 792의 상위 키워드: ['책임감', '아이', '성격', '유형', '전혀']
# 문서 793의 상위 키워드: ['부진', '수학', '구체', '대해', '가게']
# 문서 794의 상위 키워드: ['강의', '가게', '가격', '가공', '가기']
# 문서 795의 상위 키워드: ['세트', '종합', '의무교육', '선물', '가게']
# 문서 796의 상위 키워드: ['의무', '안전', '연수로', '가게', '가격']
# 문서 797의 상위 키워드: ['아동', '사항', '인권', '인지', '보호']
# 문서 798의 상위 키워드: ['적자', '일환', '유행', '특수교육', '기대']
# 문서 799의 상위 키워드: ['안전교육', '연수', '가게', '가격', '가공']
# 문서 800의 상위 키워드: ['걱정', '정보', '교육', '도움', '가게']
# 문서 801의 상위 키워드: ['죽음', '마련', '생각', '대하', '계기']
# 문서 802의 상위 키워드: ['지점', '관상', '생각', '스스로', '기억']
# 문서 803의 상위 키워드: ['부쩍', '해외여행', '언어', '때문', '부담']
# 문서 804의 상위 키워드: ['노션', '초등', '활성화', '대학', '맞춤']
# 문서 805의 상위 키워드: ['사회', '걸음', '체험', '기쁨', '행복']
# 문서 806의 상위 키워드: ['점검', '강추', '습관', '언어', '소통']
# 문서 807의 상위 키워드: ['위해', '필수', '노력', '마음', '추천']
# 문서 808의 상위 키워드: ['드라마', '복습', '가게', '가격', '가공']
# 문서 809의 상위 키워드: ['교육', '학생', '이해', '가게', '가격']
# 문서 810의 상위 키워드: ['단계', '한국어', '계기', '공부', '대한']
# 문서 811의 상위 키워드: ['법정', '신청', '연수', '가게', '가격']
# 문서 812의 상위 키워드: ['박세리', '태도', '대하', '내용', '가게']
# 문서 813의 상위 키워드: ['그림자', '마주', '치유', '시기', '마음']
# 문서 814의 상위 키워드: ['정리', '구니', '군더', '니니', '양으로']
# 문서 815의 상위 키워드: ['단편', '인과관계', '사건', '교과서', '깊이']
# 문서 816의 상위 키워드: ['매일', '아이', '연수', '가게', '가격']
# 문서 817의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 818의 상위 키워드: ['도움', '가게', '가격', '가공', '가기']
# 문서 819의 상위 키워드: ['통합교육', '교실', '이해', '연수', '가게']
# 문서 820의 상위 키워드: ['실내', '체육', '수강', '연수', '가게']
# 문서 821의 상위 키워드: ['에듀', '테크', '연수', '가게', '가격']
# 문서 822의 상위 키워드: ['다문화', '매우', '공부', '교육', '연수']
# 문서 823의 상위 키워드: ['울림', '부진', '의미', '구성', '고민']
# 문서 824의 상위 키워드: ['나날이', '중요성', '시기', '강조', '다문화']
# 문서 825의 상위 키워드: ['웹툰', '심리학', '활용', '연수', '가게']
# 문서 826의 상위 키워드: ['휴식', '그대로', '제목', '의미', '생활']
# 문서 827의 상위 키워드: ['힐링', '연수', '가게', '가격', '가공']
# 문서 828의 상위 키워드: ['안나', '자꾸', '단어', '기본', '아주']
# 문서 829의 상위 키워드: ['유지', '예방', '사고', '안전', '모두']
# 문서 830의 상위 키워드: ['안정', '여유', '마음', '연수', '가게']
# 문서 831의 상위 키워드: ['새내기', '추천', '선생님', '연수', '가게']
# 문서 832의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 833의 상위 키워드: ['만큼', '수준', '이제', '학교', '교육']
# 문서 834의 상위 키워드: ['경영', '학급', '저건', '험담', '실질']
# 문서 835의 상위 키워드: ['주위', '잠시', '자꾸', '일상', '듣기']
# 문서 836의 상위 키워드: ['긍정', '도움', '가게', '가격', '가공']
# 문서 837의 상위 키워드: ['긍정', '도움', '가게', '가격', '가공']
# 문서 838의 상위 키워드: ['화가', '상식', '기회', '가게', '가격']
# 문서 839의 상위 키워드: ['아쉬움', '연수', '가게', '가격', '가공']
# 문서 840의 상위 키워드: ['얿습니', '자격증', '한국어', '교사', '가게']
# 문서 841의 상위 키워드: ['주심', '감사', '기회', '가지', '가게']
# 문서 842의 상위 키워드: ['심화', '자격증', '연수', '가게', '가격']
# 문서 843의 상위 키워드: ['교권', '보호', '중요성', '연수', '가게']
# 문서 844의 상위 키워드: ['부진', '실질', '학습', '학생', '내용']
# 문서 845의 상위 키워드: ['바로', '활용', '수업', '연수', '가게']
# 문서 846의 상위 키워드: ['어조', '지적', '욕구', '강사', '설명']
# 문서 847의 상위 키워드: ['실질', '도움', '연수', '가게', '가격']
# 문서 848의 상위 키워드: ['제목', '다문화', '처음', '교육', '내용']
# 문서 849의 상위 키워드: ['실수', '내용', '대화', '기초', '정리']
# 문서 850의 상위 키워드: ['보람', '용어', '경제', '가게', '가격']
# 문서 851의 상위 키워드: ['남학생', '갈피', '지도', '마음', '추천']
# 문서 852의 상위 키워드: ['버킷리스트', '스페인어', '아이스크림', '하나', '기초']
# 문서 853의 상위 키워드: ['통합', '학급', '두려움', '걱정', '용기']
# 문서 854의 상위 키워드: ['눈빛', '행사', '반성', '생각', '자체']
# 문서 855의 상위 키워드: ['담화', '일련', '자치', '방식', '바탕']
# 문서 856의 상위 키워드: ['강의', '가게', '가격', '가공', '가기']
# 문서 857의 상위 키워드: ['부터', '패러다임', '이상', '평가', '지금']
# 문서 858의 상위 키워드: ['흥미진진', '길이', '가게', '가격', '가공']
# 문서 859의 상위 키워드: ['실제', '도움', '연수', '가게', '가격']
# 문서 860의 상위 키워드: ['실제', '도움', '연수', '가게', '가격']
# 문서 861의 상위 키워드: ['실제', '도움', '연수', '가게', '가격']
# 문서 862의 상위 키워드: ['조건', '최대한', '지지', '일반', '필요성']
# 문서 863의 상위 키워드: ['기획', '해외', '필요', '아쉬움', '개인']
# 문서 864의 상위 키워드: ['더욱', '현장', '학교', '효율', '목소리']
# 문서 865의 상위 키워드: ['똬악', '접수', '목소리', '바로', '아이스크림']
# 문서 866의 상위 키워드: ['시즌', '유리상자', '충족', '기대', '역시']
# 문서 867의 상위 키워드: ['영재', '일반', '경영', '위해', '학급']
# 문서 868의 상위 키워드: ['침해', '교권', '관련', '법규', '용이']
# 문서 869의 상위 키워드: ['시험', '대사', '미드', '민영', '오류로']
# 문서 870의 상위 키워드: ['숙제', '잡고', '한계', '기분', '엑셀']
# 문서 871의 상위 키워드: ['활용', '학습지도', '가정', '처리', '컴퓨터']
# 문서 872의 상위 키워드: ['유튜브', '활용', '수업', '시작', '관련']
# 문서 873의 상위 키워드: ['선사시대', '조선', '우리나라', '그림', '역사']
# 문서 874의 상위 키워드: ['정보', '가게', '가격', '가공', '가기']
# 문서 875의 상위 키워드: ['음식', '만들기', '도전', '가게', '가격']
# 문서 876의 상위 키워드: ['미국', '문화', '역사', '국제사회', '동맹국']
# 문서 877의 상위 키워드: ['의지', '어회', '대해', '영어', '공부']
# 문서 878의 상위 키워드: ['도법', '그리기', '흥미', '그림', '자신감']
# 문서 879의 상위 키워드: ['신상', '체형', '관상', '얼굴', '사람']
# 문서 880의 상위 키워드: ['변형', '영역', '응용', '초등', '고학년']
# 문서 881의 상위 키워드: ['취월', '작문', '공부', '한자', '대로']
# 문서 882의 상위 키워드: ['오니', '여기', '참고', '가게', '가격']
# 문서 883의 상위 키워드: ['교육', '확산', '널리', '전환', '필요성']
# 문서 884의 상위 키워드: ['권익', '형사', '행정', '교사', '소년법']
# 문서 885의 상위 키워드: ['알파', '툴등', '이나', '세대', '클래스']
# 문서 886의 상위 키워드: ['일어나지', '예방', '사고', '안전', '도움']
# 문서 887의 상위 키워드: ['예방', '사고', '안전', '지식', '학교']
# 문서 888의 상위 키워드: ['로서', '엄마', '마음가짐', '지혜', '가정']
# 문서 889의 상위 키워드: ['정리', '백의', '세로', '쇼핑', '더욱이']
# 문서 890의 상위 키워드: ['커피', '힐링', '시간', '대해', '가게']
# 문서 891의 상위 키워드: ['집합', '전문가', '회복', '절대', '연수']
# 문서 892의 상위 키워드: ['레시피', '요리', '최근', '가지', '관심']
# 문서 893의 상위 키워드: ['생경', '해당', '대해', '연수', '가게']
# 문서 894의 상위 키워드: ['안목', '해당', '재테크', '교사', '대한']
# 문서 895의 상위 키워드: ['고찰', '유럽', '깊이', '미술', '작품']
# 문서 896의 상위 키워드: ['살림', '집안', '마음가짐', '개선', '운영']
# 문서 897의 상위 키워드: ['알베르토', '역량', '핵심', '다문화', '교육']
# 문서 898의 상위 키워드: ['캘리그라피', '용이', '실용', '수업', '제작']
# 문서 899의 상위 키워드: ['종종', '유튜브', '활동', '통해', '연수']
# 문서 900의 상위 키워드: ['의무교육', '공감', '처음', '생활', '실제']
# 문서 901의 상위 키워드: ['학년', '두려움', '항상', '용기', '수강']
# 문서 902의 상위 키워드: ['다문화', '학교', '저희', '학생', '그동안']
# 문서 903의 상위 키워드: ['하루', '에듀', '테크', '이제', '수업']
# 문서 904의 상위 키워드: ['이탈리아', '직접', '정도', '여행', '가게']
# 문서 905의 상위 키워드: ['내용', '관련', '매우', '변호사', '상관관계']
# 문서 906의 상위 키워드: ['문제점', '얼른', '교육청', '무료', '생각']
# 문서 907의 상위 키워드: ['아이템', '매년', '시도', '수원', '부담']
# 문서 908의 상위 키워드: ['진화', '가까이', '콘텐츠', '점점', '사실']
# 문서 909의 상위 키워드: ['껄끄럽네', '임창정', '물의', '연예인', '편집']
# 문서 910의 상위 키워드: ['게임', '우리', '학생', '생각', '연수']
# 문서 911의 상위 키워드: ['게임', '우리', '학생', '생각', '연수']
# 문서 912의 상위 키워드: ['요리', '한식', '재료', '수준', '자주']
# 문서 913의 상위 키워드: ['미술', '수업', '엽서', '물감', '감각']
# 문서 914의 상위 키워드: ['재료', '디저트', '음료', '종류', '가정']
# 문서 915의 상위 키워드: ['한글', '친구', '도움', '체계', '학년']
# 문서 916의 상위 키워드: ['악기', '도전', '연습', '생전', '악보']
# 문서 917의 상위 키워드: ['활동', '사용', '띵커벨', '패들렛', '동료평가']
# 문서 918의 상위 키워드: ['영어', '기적', '전담', '유지', '듣기']
# 문서 919의 상위 키워드: ['남학생', '태도', '지도', '대한', '학생']
# 문서 920의 상위 키워드: ['문제', '보이지', '대부분', '전혀', '만들기']
# 문서 921의 상위 키워드: ['유튜브', '교재', '도움', '연수', '가게']
# 문서 922의 상위 키워드: ['통합교육', '제대로', '이해', '대해', '가게']
# 문서 923의 상위 키워드: ['관리', '캘린더', '여기저기', '메모', '노션']
# 문서 924의 상위 키워드: ['살걸', '연수', '가정은', '날수', '뒤안길']
# 문서 925의 상위 키워드: ['시각', '대해', '가게', '가격', '가공']
# 문서 926의 상위 키워드: ['금방', '시간', '내용', '가게', '가격']
# 문서 927의 상위 키워드: ['노션', '공유', '하나', '재생', '정지']
# 문서 928의 상위 키워드: ['알음', '구글', '활용', '내용', '연수']
# 문서 929의 상위 키워드: ['그대로', '접근', '현장', '조금', '영어']
# 문서 930의 상위 키워드: ['놀이', '듭니', '효과', '한번', '학습']
# 문서 931의 상위 키워드: ['영재', '요소', '수업', '도움', '가게']
# 문서 932의 상위 키워드: ['설문', '온라인', '구글', '방법', '활용']
# 문서 933의 상위 키워드: ['조력', '인간', '전반', '심리', '과학']
# 문서 934의 상위 키워드: ['활동', '도움', '가게', '가격', '가공']
# 문서 935의 상위 키워드: ['교감', '방법', '먼저', '통해', '학생']
# 문서 936의 상위 키워드: ['활동', '도움', '가게', '가격', '가공']
# 문서 937의 상위 키워드: ['영상', '한번', '정리', '내용', '가게']
# 문서 938의 상위 키워드: ['구글', '이해', '바람', '누군가', '매일']
# 문서 939의 상위 키워드: ['배려', '타인', '문제', '마음', '가게']
# 문서 940의 상위 키워드: ['직접', '사진', '상세', '다음', '정보']
# 문서 941의 상위 키워드: ['술술', '패턴', '하루', '매일', '반복']
# 문서 942의 상위 키워드: ['전진', '파이팅', '반복', '내용', '가게']
# 문서 943의 상위 키워드: ['호르몬', '명화', '높이', '해석', '대해']
# 문서 944의 상위 키워드: ['통합교육', '영향', '무엇', '통해', '아이']
# 문서 945의 상위 키워드: ['통일', '깨우침', '고려', '역량', '변화']
# 문서 946의 상위 키워드: ['교육', '다문화', '기저', '자원', '가치관']
# 문서 947의 상위 키워드: ['추후', '교육', '배경', '필요성', '이론']
# 문서 948의 상위 키워드: ['확답', '여서', '수강신청', '맥락', '교육']
# 문서 949의 상위 키워드: ['다문화', '대한', '학생', '경상남도교육청', '공짜']
# 문서 950의 상위 키워드: ['기도', '내용', '가게', '가격', '가공']
# 문서 951의 상위 키워드: ['조금', '내용', '가게', '가격', '가공']
# 문서 952의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 953의 상위 키워드: ['내용', '가게', '가격', '가공', '가기']
# 문서 954의 상위 키워드: ['면도', '조금', '내용', '가게', '가격']
# 문서 955의 상위 키워드: ['죽음', '햇던', '존재', '통해', '항상']
# 문서 956의 상위 키워드: ['구글', '대해', '활용', '가게', '가격']
# 문서 957의 상위 키워드: ['한국사', '준비', '대해', '연수', '가게']
# 문서 958의 상위 키워드: ['동사', '기본', '연수', '가게', '가격']
# 문서 959의 상위 키워드: ['초기', '문해', '덕분', '대해', '가게']
# 문서 960의 상위 키워드: ['성폭력', '실종', '유괴', '비롯', '용도']
# 문서 961의 상위 키워드: ['독후', '흥미', '활동', '추천', '내용']
# 문서 962의 상위 키워드: ['무슨', '항상', '체육', '고민', '추천']
# 문서 963의 상위 키워드: ['윤리', '러시', '리터', '반드시', '디지털']
# 문서 964의 상위 키워드: ['종류', '실질', '에듀', '테크', '사례']
# 문서 965의 상위 키워드: ['챗봇', '추천', '대해', '활용', '수업']
# 문서 966의 상위 키워드: ['실습', '파일', '화면', '경우', '하나']
# 문서 967의 상위 키워드: ['표정', '학습자', '현직', '유발', '보드게임']
# 문서 968의 상위 키워드: ['직업', '피어', '경영', '이수', '학급']
# 문서 969의 상위 키워드: ['스마트', '기계', '기기', '꿀팁', '환경']
# 문서 970의 상위 키워드: ['만화책', '캐릭터', '드라마', '제일', '세포']
# 문서 971의 상위 키워드: ['소통', '미술', '현직', '아이', '성찰']
# 문서 972의 상위 키워드: ['분야', '연습', '하나', '활동', '적용']
# 문서 973의 상위 키워드: ['계속', '이현', '저절로', '연속', '마다']
# 문서 974의 상위 키워드: ['우리말', '이론', '기회', '평소', '사용']
# 문서 975의 상위 키워드: ['현재', '환경', '미래', '시작', '교육']
# 문서 976의 상위 키워드: ['수원', '아이스크림', '부분', '기타', '중앙']
# 문서 977의 상위 키워드: ['관심', '가게', '가격', '가공', '가기']
# 문서 978의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 979의 상위 키워드: ['놀이', '과목', '공부', '아이', '활용']
# 문서 980의 상위 키워드: ['학교폭력', '사전', '발생', '예방', '운영']
# 문서 981의 상위 키워드: ['수업', '도전', '스스로', '보고', '추천']
# 문서 982의 상위 키워드: ['주기', '피드백', '구조', '글쓰기', '사고']
# 문서 983의 상위 키워드: ['보드게임', '교과', '진행', '수업', '평소']
# 문서 984의 상위 키워드: ['영재교육', '관련', '사례', '우수', '교과목']
# 문서 985의 상위 키워드: ['교육', '차원', '문제', '국가', '평가']
# 문서 986의 상위 키워드: ['연관', '요소', '인성', '놀이', '설명']
# 문서 987의 상위 키워드: ['도음', '부족함', '측면', '작년', '처음']
# 문서 988의 상위 키워드: ['도음', '부족함', '작년', '현실', '처음']
# 문서 989의 상위 키워드: ['게이미피케이션', '활용', '역시', '방학', '연수']
# 문서 990의 상위 키워드: ['다문화', '응시', '문항', '교육', '대한']
# 문서 991의 상위 키워드: ['지원', '학습자', '고려', '확인', '교육청']
# 문서 992의 상위 키워드: ['교육', '대해', '사서', '궁금증', '기존']
# 문서 993의 상위 키워드: ['교권', '사례', '설명', '이해', '대해']
# 문서 994의 상위 키워드: ['활용', '클래스', '띵커벨', '에듀', '테크']
# 문서 995의 상위 키워드: ['현직', '활용', '진심', '상세', '계획']
# 문서 996의 상위 키워드: ['레크레이션', '도움', '가게', '가격', '가공']
# 문서 997의 상위 키워드: ['영어', '공부', '가게', '가격', '가공']
# 문서 998의 상위 키워드: ['국어', '공부', '도움', '가게', '가격']
# 문서 999의 상위 키워드: ['체육', '시간', '도움', '가게', '가격']
# 문서 1000의 상위 키워드: ['국어', '문법', '가게', '가격', '가공']
# 문서 1001의 상위 키워드: ['하니', '국어', '공부', '도움', '가게']
# 문서 1002의 상위 키워드: ['인문학', '도움', '가게', '가격', '가공']
# 문서 1003의 상위 키워드: ['국어', '공부', '도움', '가게', '가격']
# 문서 1004의 상위 키워드: ['테드', '관심', '영어', '연수', '가게']
# ...
# 문서 2348의 상위 키워드: ['핵심', '부담', '구성', '내용', '가게']
# 문서 2349의 상위 키워드: ['보드게임', '포함', '실질', '흥미', '교과']
# 문서 2350의 상위 키워드: ['골치', '부엌', '세탁', '스피드', '정리']
# 문서 2351의 상위 키워드: ['수업', '매번', '다소', '교재', '시험']
# 문서 2352의 상위 키워드: ['컨트롤', '감사', '생활', '마음', '정말']
# 문서 2353의 상위 키워드: ['학습지도', '학년', '생활', '지도', '정말']
# 문서 2354의 상위 키워드: ['참으로', '강추', '교재', '공부', '가게']
# 문서 2355의 상위 키워드: ['안전교육', '가장', '이수', '연수', '가게']
# 문서 2356의 상위 키워드: ['최태성', '말씀', '강사', '가게', '가격']
# 문서 2357의 상위 키워드: ['윽로', '언어', '중심', '상황', '실제']
# 문서 2358의 상위 키워드: ['세포', '유미', '해주시', '쏙쏙', '설명']
# 문서 2359의 상위 키워드: ['기초', '모음', '스페인', '스페인어', '회화']
# 문서 2360의 상위 키워드: ['썬킴', '최고', '박정희', '후반', '강연']
# 문서 2361의 상위 키워드: ['괄호', '법정', '제목', '한번', '강의']
# 문서 2362의 상위 키워드: ['영어', '코로나', '공부', '도움', '가게']
# 문서 2363의 상위 키워드: ['캠핑', '연속', '강력', '동안', '연수']
# 문서 2364의 상위 키워드: ['강추', '내용', '내년', '최고', '핵심']
# 문서 2365의 상위 키워드: ['일만', '당황', '전혀', '문장', '자주']
# 문서 2366의 상위 키워드: ['방학', '기억', '복습', '다시', '가게']
# 문서 2367의 상위 키워드: ['도전', '시대', '한번', '정리', '다시']
# 문서 2368의 상위 키워드: ['혼동', '학습지도', '약간', '저학년', '바로']
# 문서 2369의 상위 키워드: ['과학', '교담', '만약', '원리', '신청']
# 문서 2370의 상위 키워드: ['내용', '연수', '가게', '가격', '가공']
# 문서 2371의 상위 키워드: ['무리', '이상', '담임', '저학년', '한번']
# 문서 2372의 상위 키워드: ['조금', '가게', '가격', '가공', '가기']
# 문서 2373의 상위 키워드: ['현장', '실제', '활용', '내용', '가게']
# 문서 2374의 상위 키워드: ['경제', '대해', '강의', '가게', '가격']
# 문서 2375의 상위 키워드: ['자산', '관리', '대해', '생각', '가게']
# 문서 2376의 상위 키워드: ['육아', '지도', '학생', '도움', '가게']
# 문서 2377의 상위 키워드: ['대상', '학년', '추천', '수업', '도움']
# 문서 2378의 상위 키워드: ['인쇄', '사용', '가게', '가격', '가공']
# 문서 2379의 상위 키워드: ['세계사', '사건', '가게', '가격', '가공']
# 문서 2380의 상위 키워드: ['도움', '가게', '가격', '가공', '가기']
# 문서 2381의 상위 키워드: ['선정', '메뉴', '내용', '가게', '가격']
# 문서 2382의 상위 키워드: ['문항', '화가', '평가', '구성', '내용']
# 문서 2383의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 2384의 상위 키워드: ['플랫폼', '적극', '추천', '활용', '수업']
# 문서 2385의 상위 키워드: ['기간', '지리', '해외여행', '문화', '동안']
# 문서 2386의 상위 키워드: ['감사', '내용', '연수', '가게', '가격']
# 문서 2387의 상위 키워드: ['도움', '가게', '가격', '가공', '가기']
# 문서 2388의 상위 키워드: ['도움', '가게', '가격', '가공', '가기']
# 문서 2389의 상위 키워드: ['생각', '도움', '연수', '가게', '가격']
# 문서 2390의 상위 키워드: ['전체', '내년', '과정', '현장', '내용']
# 문서 2391의 상위 키워드: ['이하', '이상', '교권', '체계', '지식']
# 문서 2392의 상위 키워드: ['독보', '차고', '지나', '에너지', '심리학']
# 문서 2393의 상위 키워드: ['굳이', '그냥', '배경', '세상', '요즘']
# 문서 2394의 상위 키워드: ['유즈', '그냥', '별로', '교재', '수업']
# 문서 2395의 상위 키워드: ['환경', '미술', '활동', '가지', '연수']
# 문서 2396의 상위 키워드: ['아이비', '우리나라', '고민', '교육', '시간']
# 문서 2397의 상위 키워드: ['전문가', '설명', '가게', '가격', '가공']
# 문서 2398의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 2399의 상위 키워드: ['여행', '학습', '이아', '이탈', '이탈리아']
# 문서 2400의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2401의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2402의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2403의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2404의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2405의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2406의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2407의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2408의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2409의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2410의 상위 키워드: ['중학교', '자녀', '강좌', '수강', '학년']
# 문서 2411의 상위 키워드: ['하나', '이행', '회피', '메세지', '실행']
# 문서 2412의 상위 키워드: ['현지', '회화', '상황', '영어', '가게']
# 문서 2413의 상위 키워드: ['직접', '구현', '디저트', '카페', '종류']
# 문서 2414의 상위 키워드: ['가득', '필요', '내용', '연수', '가게']
# 문서 2415의 상위 키워드: ['민원', '실용', '해결', '문제', '현장']
# 문서 2416의 상위 키워드: ['미국', '대해', '세계', '지식', '지도']
# 문서 2417의 상위 키워드: ['카페', '음료', '대접', '케익', '말투']
# 문서 2418의 상위 키워드: ['도구', '구글', '그냥', '아주', '활용']
# 문서 2419의 상위 키워드: ['놀이', '주네', '상상', '응용', '체육']
# 문서 2420의 상위 키워드: ['실무', '적용', '학교', '연수', '가게']
# 문서 2421의 상위 키워드: ['바로', '번창', '적용', '관계자', '연수']
# 문서 2422의 상위 키워드: ['힐링', '연수', '가게', '가격', '가공']
# 문서 2423의 상위 키워드: ['일본', '단계', '일본어', '다음', '회화']
# 문서 2424의 상위 키워드: ['듣기', '위해', '시작', '학생', '수업']
# 문서 2425의 상위 키워드: ['동사', '사별', '상급자', '영어', '선별']
# 문서 2426의 상위 키워드: ['집안', '직무', '유튜브', '연수로', '수강']
# 문서 2427의 상위 키워드: ['초등학교', '한번', '학년', '다시', '연수']
# 문서 2428의 상위 키워드: ['예금', '적금', '투기', '투자', '주식']
# 문서 2429의 상위 키워드: ['진로', '보통', '학기', '구체', '무엇']
# 문서 2430의 상위 키워드: ['특수', '매년', '학생', '통합교육', '주변']
# 문서 2431의 상위 키워드: ['방식', '진행', '연수', '가게', '가격']
# 문서 2432의 상위 키워드: ['필수', '연수', '가게', '가격', '가공']
# 문서 2433의 상위 키워드: ['활동', '학생', '연수', '가게', '가격']
# 문서 2434의 상위 키워드: ['정리', '아이템', '집안', '워낙', '기존']
# 문서 2435의 상위 키워드: ['학력', '관련', '기초', '추천', '가게']
# 문서 2436의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 2437의 상위 키워드: ['법적', '인정', '시간', '연수', '가게']
# 문서 2438의 상위 키워드: ['배속', '질문', '출제', '점수', '생각']
# 문서 2439의 상위 키워드: ['배속', '질문', '출제', '점수', '생각']
# 문서 2440의 상위 키워드: ['현장', '활용', '가게', '가격', '가공']
# 문서 2441의 상위 키워드: ['라인', '작고', '도서', '가이드', '글씨']
# 문서 2442의 상위 키워드: ['엑셀', '기능', '차근차근', '연습', '설명']
# 문서 2443의 상위 키워드: ['단시간', '연습', '쏙쏙', '기억', '반복']
# 문서 2444의 상위 키워드: ['육아', '강력', '제시', '방향', '매우']
# 문서 2445의 상위 키워드: ['표현', '여행', '영어', '설명', '연수']
# 문서 2446의 상위 키워드: ['오프라인', '요가', '보기', '매일', '온라인']
# 문서 2447의 상위 키워드: ['제시', '방향', '영어', '공부', '추천']
# 문서 2448의 상위 키워드: ['내년', '해결', '한번', '연수', '가게']
# 문서 2449의 상위 키워드: ['요가', '오프라인', '힐링', '방법', '연수']
# 문서 2450의 상위 키워드: ['시기', '선택', '연수로', '아주', '기초']
# 문서 2451의 상위 키워드: ['자율', '실습', '능력', '시대', '가장']
# 문서 2452의 상위 키워드: ['상실', '아픔', '정심', '영화', '인간관계']
# 문서 2453의 상위 키워드: ['이야기', '학생', '내용', '가게', '가격']
# 문서 2454의 상위 키워드: ['시간', '충만', '가르침', '여유', '예전']
# 문서 2455의 상위 키워드: ['효율', '측면', '장점', '의무교육', '종류']
# 문서 2456의 상위 키워드: ['소설', '파친코', '근현대사', '한국', '통해']
# 문서 2457의 상위 키워드: ['세포', '유미', '심리학', '연수', '가게']
# 문서 2458의 상위 키워드: ['동기', '외적', '호흡', '내적', '불안']
# 문서 2459의 상위 키워드: ['역사', '내용', '연수기', '이군', '품질']
# 문서 2460의 상위 키워드: ['근대사', '우리나라', '계기', '정리', '연수']
# 문서 2461의 상위 키워드: ['진로', '수업', '바탕', '참여', '노력']
# 문서 2462의 상위 키워드: ['대입', '공부', '간접', '고교', '고등학교']
# 문서 2463의 상위 키워드: ['모두', '한번', '연수', '가게', '가격']
# 문서 2464의 상위 키워드: ['진학', '전문성', '지인', '진로', '상담']
# 문서 2465의 상위 키워드: ['나라', '공부', '세계', '유산', '연수']
# 문서 2466의 상위 키워드: ['영어', '자신감', '시작', '그동안', '이제']
# 문서 2467의 상위 키워드: ['덕분', '연수', '가게', '가격', '가공']
# 문서 2468의 상위 키워드: ['지도', '학생', '도움', '가게', '가격']
# 문서 2469의 상위 키워드: ['설민석', '워낙', '해주시', '점수', '시험']
# 문서 2470의 상위 키워드: ['가치', '연수', '가게', '가격', '가공']
# 문서 2471의 상위 키워드: ['구성', '이해', '연수', '가게', '가격']
# 문서 2472의 상위 키워드: ['기초', '영어', '가게', '가격', '가공']
# 문서 2473의 상위 키워드: ['기초', '영어', '가게', '가격', '가공']
# 문서 2474의 상위 키워드: ['몰입', '시간', '강의', '가게', '가격']
# 문서 2475의 상위 키워드: ['강의', '가게', '가격', '가공', '가기']
# 문서 2476의 상위 키워드: ['강좌', '러시', '리터', '인식', '종종']
# 문서 2477의 상위 키워드: ['변화', '시간', '수업', '연수', '가게']
# 문서 2478의 상위 키워드: ['가요', '간단', '한국사', '정리', '시간']
# 문서 2479의 상위 키워드: ['유연성', '마음', '상처', '공감', '교실']
# 문서 2480의 상위 키워드: ['그림책', '활용', '소개', '자료', '평소']
# 문서 2481의 상위 키워드: ['내면', '교사', '아이', '연수', '가게']
# 문서 2482의 상위 키워드: ['최근', '가장', '추천', '연수', '가게']
# 문서 2483의 상위 키워드: ['쏙쏙', '강의', '가게', '가격', '가공']
# 문서 2484의 상위 키워드: ['시즌', '역시', '이수', '연수', '가게']
# 문서 2485의 상위 키워드: ['아이', '이해', '도움', '가게', '가격']
# 문서 2486의 상위 키워드: ['아이', '이해', '도움', '가게', '가격']
# 문서 2487의 상위 키워드: ['관리', '교실', '정리', '통해', '가게']
# 문서 2488의 상위 키워드: ['효율', '이용', '운영', '구글', '학급']
# 문서 2489의 상위 키워드: ['만들기', '놀이', '학급', '통해', '도움']
# 문서 2490의 상위 키워드: ['근현대사', '한국', '핵심', '설명', '연수']
# 문서 2491의 상위 키워드: ['최고', '정말', '연수', '가게', '가격']
# 문서 2492의 상위 키워드: ['최고', '정말', '연수', '가게', '가격']
# 문서 2493의 상위 키워드: ['문해', '시점', '능력', '요즘', '무엇']
# 문서 2494의 상위 키워드: ['동남아', '베트남어', '태국어', '언어', '일본어']
# 문서 2495의 상위 키워드: ['고도원', '연수', '태도', '유지', '긍정']
# 문서 2496의 상위 키워드: ['필수', '연수', '통해', '이수', '업무']
# 문서 2497의 상위 키워드: ['강의', '가게', '가격', '가공', '가기']
# 문서 2498의 상위 키워드: ['요긴', '담임', '저학년', '연수', '가게']
# 문서 2499의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 2500의 상위 키워드: ['다문화', '생각', '연수', '가게', '가격']
# 문서 2501의 상위 키워드: ['학력', '부진', '때문', '기초', '고민']
# 문서 2502의 상위 키워드: ['에듀', '테크', '시대', '연수', '가게']
# 문서 2503의 상위 키워드: ['표현', '상황', '여러', '가게', '가격']
# 문서 2504의 상위 키워드: ['두시', '선생님', '신규', '경력', '동료']
# 문서 2505의 상위 키워드: ['결코', '보람', '후회', '다른', '추천']
# 문서 2506의 상위 키워드: ['궁궐', '역사', '조선시대', '탐사', '발생']
# 문서 2507의 상위 키워드: ['통합', '경영', '아이디어', '학급', '대한']
# 문서 2508의 상위 키워드: ['원인', '부진', '학습', '이해', '가게']
# 문서 2509의 상위 키워드: ['영상', '힐링', '시간', '가게', '가격']
# 문서 2510의 상위 키워드: ['흥미', '한국사', '통해', '강의', '가게']
# 문서 2511의 상위 키워드: ['자치', '아이디어', '운영', '활동', '대한']
# 문서 2512의 상위 키워드: ['자산', '관리', '은퇴', '노하우', '이후']
# 문서 2513의 상위 키워드: ['모처럼', '가수', '노래', '소리', '목소리']
# 문서 2514의 상위 키워드: ['컬러링', '가운데', '예술', '작업', '차근차근']
# 문서 2515의 상위 키워드: ['우리', '생활', '멀리', '무대', '슬픔']
# 문서 2516의 상위 키워드: ['체육', '여러가지', '진행', '방법', '수업']
# 문서 2517의 상위 키워드: ['위주', '회화', '도움', '연수', '가게']
# 문서 2518의 상위 키워드: ['아이', '강의', '도움', '가게', '가격']
# 문서 2519의 상위 키워드: ['만듭니', '어순', '시원', '스쿨', '은퇴']
# 문서 2520의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 2521의 상위 키워드: ['보석', '미덕', '모로', '장점', '학급']
# 문서 2522의 상위 키워드: ['메뉴', '가장', '다른', '추천', '강의']
# 문서 2523의 상위 키워드: ['근래', '권장', '모든', '아주', '교사']
# 문서 2524의 상위 키워드: ['문장', '뉘앙스', '복학', '정리', '귀로']
# 문서 2525의 상위 키워드: ['강의', '교직', '생활', '내용', '도움']
# 문서 2526의 상위 키워드: ['즐거움', '기간', '마음', '연수', '가게']
# 문서 2527의 상위 키워드: ['독학', '구매', '동안', '연습', '교재']
# 문서 2528의 상위 키워드: ['알음', '표현', '강의', '가게', '가격']
# 문서 2529의 상위 키워드: ['자연', '영어', '방법', '가게', '가격']
# 문서 2530의 상위 키워드: ['인간', '관계', '보편', '조명', '현상']
# 문서 2531의 상위 키워드: ['연산', '지도', '방법', '글쓰기', '동화']
# 문서 2532의 상위 키워드: ['배움', '바탕', '모든', '지도', '추천']
# 문서 2533의 상위 키워드: ['업데이트', '띵커벨', '패들렛', '기능', '일부']
# 문서 2534의 상위 키워드: ['대본', '생동감', '성의', '생각', '그대로']
# 문서 2535의 상위 키워드: ['역사', '강의', '과거', '중간', '개념']
# 문서 2536의 상위 키워드: ['일부', '학문', '아두', '매번', '외국인']
# 문서 2537의 상위 키워드: ['출퇴근길', '듣기', '느낌', '부담', '강의']
# 문서 2538의 상위 키워드: ['문안', '필수', '연수', '가게', '가격']
# 문서 2539의 상위 키워드: ['문안', '서로', '대화', '진행', '가게']
# 문서 2540의 상위 키워드: ['토픽', '대화', '원어민', '미국', '생활']
# 문서 2541의 상위 키워드: ['대상', '효과', '학급', '아이', '생각']
# 문서 2542의 상위 키워드: ['문장', '두서', '드라마', '뭔가', '영상']
# 문서 2543의 상위 키워드: ['술술', '집중', '꼬꼬', '만인', '해박']
# 문서 2544의 상위 키워드: ['이유', '사례', '이야기', '추천', '연수']
# 문서 2545의 상위 키워드: ['가정', '주변', '모든', '변화', '연수로']
# 문서 2546의 상위 키워드: ['교양', '김영철', '타일러', '재미', '연수']
# 문서 2547의 상위 키워드: ['요청', '지속', '이상', '시대', '사회']
# 문서 2548의 상위 키워드: ['연수', '수강', '기간', '계속', '감독']
# 문서 2549의 상위 키워드: ['지혜', '최태성', '주시', '한국사', '역사']
# 문서 2550의 상위 키워드: ['요약', '명화', '접목', '힐링', '마음']
# 문서 2551의 상위 키워드: ['놀이', '방법', '연수', '가게', '가격']
# 문서 2552의 상위 키워드: ['가면', '가기', '해외', '여행', '연수']
# 문서 2553의 상위 키워드: ['정리', '가이드', '여행', '별로', '주제']
# 문서 2554의 상위 키워드: ['교재', '내용', '가게', '가격', '가공']
# 문서 2555의 상위 키워드: ['바로', '현장', '기초', '활용', '내용']
# 문서 2556의 상위 키워드: ['시험', '공부', '문법', '연수', '교재']
# 문서 2557의 상위 키워드: ['기회', '리본', '성취', '작품', '반복']
# 문서 2558의 상위 키워드: ['요약', '내용', '가게', '가격', '가공']
# 문서 2559의 상위 키워드: ['타로', '단연', '사서', '연수', '자주']
# 문서 2560의 상위 키워드: ['손글씨', '즐거움', '재료', '온라인', '연수로']
# 문서 2561의 상위 키워드: ['중간', '과열', '주요', '도시', '일본']
# 문서 2562의 상위 키워드: ['고사', '보람', '출석', '오늘', '이수']
# 문서 2563의 상위 키워드: ['그림', '무언', '소질', '뜻밖', '화실']
# 문서 2564의 상위 키워드: ['도면', '종이접기', '난이도', '재미', '저학년']
# 문서 2565의 상위 키워드: ['패키지', '뚜루뚜루', '로봇', '엔트리', '코딩']
# 문서 2566의 상위 키워드: ['미술가', '전체', '미술', '작품', '이야기']
# 문서 2567의 상위 키워드: ['변기', '식기세척기', '심지어', '면서', '용법']
# 문서 2568의 상위 키워드: ['교육과정', '과학', '학년', '추천', '선생님']
# 문서 2569의 상위 키워드: ['이탈리아', '깊이', '이해', '도움', '가게']
# 문서 2570의 상위 키워드: ['분석', '방안', '원인', '혼자', '제시']
# 문서 2571의 상위 키워드: ['일상', '생활', '사용', '영어', '도움']
# 문서 2572의 상위 키워드: ['습득', '언어', '기본', '정리', '다시']
# 문서 2573의 상위 키워드: ['맥락', '문해', '관심', '통해', '이해']
# 문서 2574의 상위 키워드: ['남자', '아이', '이해', '도움', '가게']
# 문서 2575의 상위 키워드: ['부진', '이야기', '학습', '지도', '학생']
# 문서 2576의 상위 키워드: ['실과', '직무', '요리', '실생활', '부담']
# 문서 2577의 상위 키워드: ['세계', '기회', '여행', '가게', '가격']
# 문서 2578의 상위 키워드: ['격차', '학급', '학생', '연수', '가게']
# 문서 2579의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 2580의 상위 키워드: ['현황', '소화', '꼭꼭', '외국', '비교']
# 문서 2581의 상위 키워드: ['가정', '정리', '학교', '활용', '가게']
# 문서 2582의 상위 키워드: ['심리학', '편도', '세포', '유미', '심화']
# 문서 2583의 상위 키워드: ['실속', '진짜', '교육', '내용', '가게']
# 문서 2584의 상위 키워드: ['해도', '수양', '간만', '마우스', '잡고']
# 문서 2585의 상위 키워드: ['성교육', '응용', '구성', '현장', '내용']
# 문서 2586의 상위 키워드: ['썬킨님', '연결', '근현대사', '이야기', '정리']
# 문서 2587의 상위 키워드: ['디지털', '도전', '처음', '추천', '강의']
# 문서 2588의 상위 키워드: ['추천', '가게', '가격', '가공', '가기']
# 문서 2589의 상위 키워드: ['토론', '모서리', '용기', '적극', '참여']
# 문서 2590의 상위 키워드: ['방식', '용기', '방향', '운영', '의미']
# 문서 2591의 상위 키워드: ['세계', '힐링', '연수', '가게', '가격']
# 문서 2592의 상위 키워드: ['그림책', '적용', '초등', '수업', '고학년']
# 문서 2593의 상위 키워드: ['부분', '시해', '순서', '우선', '혼자']
# 문서 2594의 상위 키워드: ['정리', '하라', '개선', '인상', '매일']
# 문서 2595의 상위 키워드: ['소개', '여러', '도움', '연수', '가게']
# 문서 2596의 상위 키워드: ['이해', '가게', '가격', '가공', '가기']
# 문서 2597의 상위 키워드: ['목적', '연수', '가게', '가격', '가공']
# 문서 2598의 상위 키워드: ['학생', '학기', '상담', '활동', '조금']
# 문서 2599의 상위 키워드: ['엄두', '걱정', '구체', '학년', '설명']
# 문서 2600의 상위 키워드: ['주식', '상식', '기초', '대한', '연수']
# 문서 2601의 상위 키워드: ['이야기', '호르몬', '관계', '그림', '가게']
# 문서 2602의 상위 키워드: ['개인', '분야', '느낌', '연수로', '기본']
# 문서 2603의 상위 키워드: ['기능', '구글', '여러', '가게', '가격']
# 문서 2604의 상위 키워드: ['제겐', '스마트폰', '더욱', '내용', '연수']
# 문서 2605의 상위 키워드: ['어플', '다운로드', '아이패트', '갤럭시', '패드']
# 문서 2606의 상위 키워드: ['대해', '가게', '가격', '가공', '가기']
# 문서 2607의 상위 키워드: ['안전', '연수', '되풀이', '양질', '그간']
# 문서 2608의 상위 키워드: ['교육', '성교육', '진행', '영감', '국한']
# 문서 2609의 상위 키워드: ['직업', '권위자', '질도', '시야', '옛날']
# 문서 2610의 상위 키워드: ['힌트', '마주', '중학교', '남자', '심리']
# 문서 2611의 상위 키워드: ['도움', '연수', '가게', '가격', '가공']
# 문서 2612의 상위 키워드: ['구글', '대한', '활용', '도움', '가게']
# 문서 2613의 상위 키워드: ['안내', '주시', '차근차근', '도구', '준비']
# 문서 2614의 상위 키워드: ['상황', '관계', '심리', '문제기', '역할극']
# 문서 2615의 상위 키워드: ['정보통', '윤리', '필수', '연수로', '교육']
# 문서 2616의 상위 키워드: ['화두', '예시', '주제', '신청', '내용']
# 문서 2617의 상위 키워드: ['개별', '학습', '부진', '친구', '굴레']
# 문서 2618의 상위 키워드: ['역시', '다른', '강사', '연수', '가게']
# 문서 2619의 상위 키워드: ['기분', '세계', '여행', '가게', '가격']
# 문서 2620의 상위 키워드: ['무료', '연수로', '연수', '가게', '가격']
# 문서 2621의 상위 키워드: ['창고', '보물', '대로', '구글', '활용']
# 문서 2622의 상위 키워드: ['프로젝터', '강연', '화면', '선생님', '작업']
# 문서 2623의 상위 키워드: ['사용', '일상', '수업', '만날', '직무']
# 문서 2624의 상위 키워드: ['다문화', '매우', '대한', '활용', '내용']
# 문서 2625의 상위 키워드: ['주말', '학교', '고가', '관공서', '치면']
# 문서 2626의 상위 키워드: ['행복감', '그리기', '그림', '매우', '연수']
# 문서 2627의 상위 키워드: ['집밥', '가게', '가격', '가공', '가기']
# 문서 2628의 상위 키워드: ['연수', '가게', '가격', '가공', '가기']
# 문서 2629의 상위 키워드: ['사람', '대한', '이해', '도움', '가게']
# 문서 2630의 상위 키워드: ['규율', '사이', '자유', '책임', '학년']
# 문서 2631의 상위 키워드: ['수채화', '대상', '이용', '방법', '대해']
# 문서 2632의 상위 키워드: ['가이드라인', '살림살이', '청소', '편이', '제시']
# 문서 2633의 상위 키워드: ['혼자', '교재', '교실', '신청', '추천']
# 문서 2634의 상위 키워드: ['교안', '파일', '문해', '기초', '강의']
# 문서 2635의 상위 키워드: ['극복', '어려움', '방법', '학생', '가게']
# 문서 2636의 상위 키워드: ['의무교육', '법정', '이수', '기회', '가게']
# 문서 2637의 상위 키워드: ['메뉴', '요리', '과정', '정말', '가게']
# 문서 2638의 상위 키워드: ['한국사', '때론', '상이', '옛날', '지난']
# 문서 2639의 상위 키워드: ['특색', '줄넘기', '전담', '가기', '체육']
# 문서 2640의 상위 키워드: ['우울', '객관', '사랑', '스스로', '요즘']
# 문서 2641의 상위 키워드: ['자의', '입문', '수준', '차근차근', '기능']
# 문서 2642의 상위 키워드: ['스토리', '전달', '아이', '강의', '가게']
# 문서 2643의 상위 키워드: ['정보', '업무', '사용', '도움', '가게']
# 문서 2644의 상위 키워드: ['강의', '가게', '가격', '가공', '가기']
# 문서 2645의 상위 키워드: ['스트레스', '상황', '여러', '도움', '연수']
# 문서 2646의 상위 키워드: ['가사', '팝송', '영어', '거기', '현지']
# 문서 2647의 상위 키워드: ['성재', '군대', '안녕', '연락', '훈련']
# 문서 2648의 상위 키워드: ['정리', '대해', '가게', '가격', '가공']
# 문서 2649의 상위 키워드: ['패들렛', '사용', '강의', '가게', '가격']
# 문서 2650의 상위 키워드: ['스킬', '도구', '요즘', '활용', '수업']
# 문서 2651의 상위 키워드: ['무민', '영어', '영국', '차이', '미국']
# 문서 2652의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 2653의 상위 키워드: ['마음', '진짜', '친구', '스스로', '표현']
# 문서 2654의 상위 키워드: ['스스로', '감정', '마음', '노력', '강의']
# 문서 2655의 상위 키워드: ['구글', '교사', '활용', '연수', '가게']
# 문서 2656의 상위 키워드: ['격차', '학습', '대해', '연수', '가게']
# 문서 2657의 상위 키워드: ['죽음', '대해', '연수', '가게', '가격']
# 문서 2658의 상위 키워드: ['썬킴님', '항상', '연수로', '역사', '가게']
# 문서 2659의 상위 키워드: ['진짜', '미국', '생활', '사용', '영어']
# 문서 2660의 상위 키워드: ['실제', '수업', '도움', '가게', '가격']
# 문서 2661의 상위 키워드: ['가게', '가격', '가공', '가기', '가까이']
# 문서 2662의 상위 키워드: ['연수로', '아주', '교육', '대해', '가게']
# 문서 2663의 상위 키워드: ['중심', '평가', '과정', '가게', '가격']
# 문서 2664의 상위 키워드: ['체육', '놀이', '설명', '대해', '가게']
# 문서 2665의 상위 키워드: ['감상', '과정', '힐링', '가게', '가격']
# 문서 2666의 상위 키워드: ['성교육', '대해', '가게', '가격', '가공']
# 문서 2667의 상위 키워드: ['포츠', '뉴스', '체육', '최고', '자신감']
# 문서 2668의 상위 키워드: ['여행가', '가게', '가격', '가공', '가기']
# 문서 2669의 상위 키워드: ['심리학', '다시', '대해', '가게', '가격']
# 문서 2670의 상위 키워드: ['한국사', '다시', '대해', '가게', '가격']
# 문서 2671의 상위 키워드: ['펄스', '컬러', '대해', '가게', '가격']
# 문서 2672의 상위 키워드: ['와인', '대해', '가게', '가격', '가공']
# 문서 2673의 상위 키워드: ['베이', '차근차근', '처음', '기초', '사람']
# 문서 2674의 상위 키워드: ['놀이', '바로', '여러', '학급', '실제']
# 문서 2675의 상위 키워드: ['영재교육', '기본', '가게', '가격', '가공']

# %%
tfidf_df=pd.DataFrame(tfidf.fit_transform(reviews).toarray(), columns=tfidf.get_feature_names_out())

# %%
tfidf_sum = tfidf_df.sum(axis=0)
sorted_tfidf = tfidf_sum.sort_values(ascending=False)

# %%
sorted_tfidf_df = pd.DataFrame(sorted_tfidf, columns=["TF-IDF"])

# %%
sorted_tfidf_df
# Out:
#             TF-IDF
# _x000d_  97.208409
# 유익한      63.285451
# 연수였습니다   61.753442
# 도움이      58.340212
# 감사합니다    57.916099
# ...            ...
# 입었습니다     0.041575
# 팔러        0.041575
# 오염시킵니다    0.041575
# 만원도       0.041575
# 내용일       0.041575
#
# [17489 rows x 1 columns]

# %%
data_input_reduced
# Out:
#                                    제목    시간          날짜  별점  \
# 0         하루 20분! 나만을 위한 '나마스떼' 힐링 요가  15차시  2024-01-28   5
# 1                       폭력 교실에 맞서는 용기  30차시  2024-03-26   4
# 2                 아이들의 내면이 단단해지는 격려수업  15차시  2024-01-06   5
# 3                           정재승의 미래학교  30차시  2023-12-27   5
# 4    MBTI로 가화만사성! 성격유형으로 보는 부부&자녀 대화법   5차시  2024-03-20   5
# ..                                ...   ...         ...  ..
# 295                기초학력교육, 관계형성이 먼저다.  15차시  2024-05-08   5
# 296            가르침에 지친 당신을 위한 방구석 인문학  30차시  2024-04-09   5
# 297   Made at Home, 나만의 작은 홈카페 & 홈베이킹  15차시  2023-12-20   4
# 298                   기초학력의 첫걸음, 수학교육  15차시  2024-06-10   5
# 299   Made at Home, 나만의 작은 홈카페 & 홈베이킹  15차시  2024-01-03   4
#
#                                             리뷰제목  연수분야       가격    대상  label
# 0                                           나마스떼  자기계발  40,000원  전체대상      1
# 1                                      잘 들었습니다.   생활지도  75,000원    중등      0
# 2                                          좋은 연수  생활지도  50,000원  전체대상      1
# 3                                큰별쌤 최태성의 별★별한국사  학습지도  75,000원  전체대상      1
# 4                         요즘..이거 모르면 대화가 안되더라구요.  자기계발  15,000원  전체대상      1
# ..                                           ...   ...      ...   ...    ...
# 295                                  영원한 과제-기초학력  학습지도  40,000원   유초등      1
# 296                                        좋습니다.  자기계발  75,000원  전체대상      1
# 297                               홈카페 홈베이킹 연수 후기  자기계발  40,000원  전체대상      0
# 298                                    기초학력의 중요성  교과지도  40,000원  전체대상      1
# 299  기분을 전환시키는 음료와 맛있는 홈베이킹이 좋았습니다. 만들어서 먹고 싶네요.  자기계발  40,000원  전체대상      0
#
# [300 rows x 9 columns]

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')
# 파일을 불러옴
data = pd.read_excel('./undersample_data.xlsx')

# 감정 라벨 추가 (예시로 긍정=1, 부정=0으로 라벨링)
data['감정'] = data['별점'].apply(lambda x: 1 if x >= 4 else 0)

# 리뷰내용 컬럼의 모든 텍스트를 가져옴
reviews = data['리뷰내용'].dropna().tolist()
labels = data['감정'].dropna().tolist()

okt = Okt()

# 모든 문서의 명사 추출 후 하나의 텍스트로 결합
processed_docs = []
for doc in reviews:
    nouns = okt.nouns(doc)
    processed_docs.append(" ".join(nouns))

# TF-IDF 벡터화 객체 생성
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(processed_docs)

# 학습 데이터와 테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, labels, test_size=0.2, random_state=42)

# 로지스틱 회귀 모델 학습
model = LogisticRegression()
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# 감정 분석 결과 추가
data['감정_예측'] = model.predict(tfidf_matrix)

# 감정 분석 결과 출력 (데이터프레임 형태)
result_df = data[['리뷰내용', '별점', '감정', '감정_예측']]

# 긍정 리뷰 예시 10개
positive_examples = result_df[result_df['감정_예측'] == 1].head(10)

# 부정 리뷰 예시 10개
negative_examples = result_df[result_df['감정_예측'] == 0].head(10)

# 긍정, 부정 리뷰 예시 출력
print("Positive Reviews (10 examples):")
print(positive_examples)

print("\nNegative Reviews (10 examples):")
print(negative_examples)

# 감정 분석 결과와 긍정/부정 리뷰 예시를 데이터프레임으로 저장
result_df.to_excel('sentiment_analysis_results.xlsx', index=False)
positive_examples.to_excel('positive_reviews_examples.xlsx', index=False)
negative_examples.to_excel('negative_reviews_examples.xlsx', index=False)

# 추가 분석

# 리뷰 길이 분석
data['리뷰길이'] = data['리뷰내용'].apply(lambda x: len(x.split()))
plt.figure(figsize=(10, 6))
sns.histplot(data, x='리뷰길이', hue='감정', multiple='stack', palette='viridis')
plt.title('리뷰 길이 분포')
plt.xlabel('리뷰 길이 (단어 수)')
plt.ylabel('리뷰 수')
plt.show()

# 워드 클라우드 생성
positive_text = " ".join(review for review in data[data['감정'] == 1]['리뷰내용'])
negative_text = " ".join(review for review in data[data['감정'] == 0]['리뷰내용'])
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf', background_color='white').generate(positive_text)
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf', background_color='white').generate(negative_text)
wordcloud_positive = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
wordcloud_negative = WordCloud(width=800, height=400, background_color='white').generate(negative_text)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud')
plt.axis('off')

plt.show()

# 평점 분포 분석
plt.figure(figsize=(10, 6))
sns.countplot(x='별점', data=data, palette='viridis')
plt.title('평점 분포')
plt.xlabel('별점')
plt.ylabel('리뷰 수')
plt.show()

# 리뷰 시간 분석 (가정: '날짜' 컬럼이 있음)
data['날짜'] = pd.to_datetime(data['날짜'])
data['연도'] = data['날짜'].dt.year
data['월'] = data['날짜'].dt.month

plt.figure(figsize=(10, 6))
sns.countplot(x='연도', hue='감정', data=data, palette='viridis')
plt.title('연도별 리뷰 수')
plt.xlabel('연도')
plt.ylabel('리뷰 수')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='월', hue='감정', data=data, palette='viridis')
plt.title('월별 리뷰 수')
plt.xlabel('월')
plt.ylabel('리뷰 수')
plt.show()
# Out:
# Accuracy: 0.9714285714285714
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.97      1.00      0.99       136
#
#     accuracy                           0.97       140
#    macro avg       0.49      0.50      0.49       140
# weighted avg       0.94      0.97      0.96       140
#
# Positive Reviews (10 examples):
#                                                 리뷰내용  별점  감정  감정_예측
# 0                                 많이 그려봐야 할 것 같습니다^^   5   1      1
# 1  문해력 수업의 기초 강의입니다._x000D_\n자세한 교안 파일이 올려져 있으면 더...   5   1      1
# 2                        생각보다 훨씬 재미있고 유익한 영어 연수였습니다.   5   1      1
# 3  직업눌이, 학급 경영에 따뜻함이 피어납니다. 연수 이수 후 2년째 직업놀이 중입니다...   5   1      1
# 4  한국어교원양성과정 Ⅰ연수 수강이 쉽지는 않았다.  나에겐 고등 국어 문법을 다시 공...   5   1      1
# 5  교실에 있는 스마트 기기를 어느 정도 사용한다고 생각했는데, 이 연수를 통해 보다 ...   5   1      1
# 6  입문자용으로 구글 사용의 전체적 맥락을 잡기에 좋은연수였습니다. 그리고 구글을 사용...   5   1      1
# 7                       심화해서 잘 연수하고 자격증까지 받았으면 좋겠습니다   5   1      1
# 8                                       좋은 강의 감사합니다.   5   1      1
# 9  아동인권과 더불어 교권보호에 관한 사항을 정확하게 인지하고 있어야만 무너지고 있는 ...   5   1      1
#
# Negative Reviews (10 examples):
# Empty DataFrame
# Columns: [리뷰내용, 별점, 감정, 감정_예측]
# Index: []
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\wltjr\AppData\Local\Temp\ipykernel_21928\2515287275.py:104: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='별점', data=data, palette='viridis')

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.font_manager as fm

plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# 한글 폰트 설정
font_path = 'D:/0802pj/NanumGothic/29131424179.ttf'  # 한글 폰트 파일 경로 설정
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

# 파일을 불러옴
data = pd.read_excel('./undersample_data.xlsx')

# 감정 라벨 추가 (예시로 긍정=1, 부정=0으로 라벨링)
data['감정'] = data['별점'].apply(lambda x: 1 if x >= 4 else 0)

# 리뷰내용 컬럼의 모든 텍스트를 가져옴
reviews = data['리뷰내용'].dropna().tolist()
labels = data['감정'].dropna().tolist()

okt = Okt()

# 모든 문서의 명사 추출 후 하나의 텍스트로 결합
processed_docs = []
for doc in reviews:
    nouns = okt.nouns(doc)
    processed_docs.append(" ".join(nouns))

# TF-IDF 벡터화 객체 생성
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(processed_docs)

# 학습 데이터와 테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, labels, test_size=0.2, random_state=42)

# 로지스틱 회귀 모델 학습
model = LogisticRegression()
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# 감정 분석 결과 추가
data['감정_예측'] = model.predict(tfidf_matrix)

# 감정 분석 결과 출력 (데이터프레임 형태)
result_df = data[['리뷰내용', '별점', '감정', '감정_예측']]

# 긍정 리뷰 예시 10개
positive_examples = result_df[result_df['감정_예측'] == 1].head(10)

# 부정 리뷰 예시 10개
negative_examples = result_df[result_df['감정_예측'] == 0].head(10)

# 긍정, 부정 리뷰 예시 출력
print("Positive Reviews (10 examples):")
print(positive_examples)

print("\nNegative Reviews (10 examples):")
print(negative_examples)

# 감정 분석 결과와 긍정/부정 리뷰 예시를 데이터프레임으로 저장
result_df.to_excel('sentiment_analysis_results.xlsx', index=False)
positive_examples.to_excel('positive_reviews_examples.xlsx', index=False)
negative_examples.to_excel('negative_reviews_examples.xlsx', index=False)

# 추가 분석

# 리뷰 길이 분석
data['리뷰길이'] = data['리뷰내용'].apply(lambda x: len(x.split()))
plt.figure(figsize=(10, 6))
sns.histplot(data, x='리뷰길이', hue='감정', multiple='stack', palette='viridis')
plt.title('리뷰 길이 분포')
plt.xlabel('리뷰 길이 (단어 수)')
plt.ylabel('리뷰 수')
plt.show()

# 워드 클라우드 생성
positive_text = " ".join(review for review in data[data['감정'] == 1]['리뷰내용'])
negative_text = " ".join(review for review in data[data['감정'] == 0]['리뷰내용'])

wordcloud_positive = WordCloud(width=800, height=400, background_color='white', font_path=font_path).generate(positive_text)
wordcloud_negative = WordCloud(width=800, height=400, background_color='white', font_path=font_path).generate(negative_text)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud')
plt.axis('off')

plt.show()

# 평점 분포 분석
plt.figure(figsize=(10, 6))
sns.countplot(x='별점', data=data, palette='viridis')
plt.title('평점 분포')
plt.xlabel('별점')
plt.ylabel('리뷰 수')
plt.show()

# 리뷰 시간 분석 (가정: '날짜' 컬럼이 있음)
data['날짜'] = pd.to_datetime(data['날짜'])
data['연도'] = data['날짜'].dt.year
data['월'] = data['날짜'].dt.month

plt.figure(figsize=(10, 6))
sns.countplot(x='연도', hue='감정', data=data, palette='viridis')
plt.title('연도별 리뷰 수')
plt.xlabel('연도')
plt.ylabel('리뷰 수')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='월', hue='감정', data=data, palette='viridis')
plt.title('월별 리뷰 수')
plt.xlabel('월')
plt.ylabel('리뷰 수')
plt.show()
# Out:
# Accuracy: 0.9714285714285714
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.97      1.00      0.99       136
#
#     accuracy                           0.97       140
#    macro avg       0.49      0.50      0.49       140
# weighted avg       0.94      0.97      0.96       140
#
# Positive Reviews (10 examples):
#                                                 리뷰내용  별점  감정  감정_예측
# 0                                 많이 그려봐야 할 것 같습니다^^   5   1      1
# 1  문해력 수업의 기초 강의입니다._x000D_\n자세한 교안 파일이 올려져 있으면 더...   5   1      1
# 2                        생각보다 훨씬 재미있고 유익한 영어 연수였습니다.   5   1      1
# 3  직업눌이, 학급 경영에 따뜻함이 피어납니다. 연수 이수 후 2년째 직업놀이 중입니다...   5   1      1
# 4  한국어교원양성과정 Ⅰ연수 수강이 쉽지는 않았다.  나에겐 고등 국어 문법을 다시 공...   5   1      1
# 5  교실에 있는 스마트 기기를 어느 정도 사용한다고 생각했는데, 이 연수를 통해 보다 ...   5   1      1
# 6  입문자용으로 구글 사용의 전체적 맥락을 잡기에 좋은연수였습니다. 그리고 구글을 사용...   5   1      1
# 7                       심화해서 잘 연수하고 자격증까지 받았으면 좋겠습니다   5   1      1
# 8                                       좋은 강의 감사합니다.   5   1      1
# 9  아동인권과 더불어 교권보호에 관한 사항을 정확하게 인지하고 있어야만 무너지고 있는 ...   5   1      1
#
# Negative Reviews (10 examples):
# Empty DataFrame
# Columns: [리뷰내용, 별점, 감정, 감정_예측]
# Index: []
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48624 (\N{HANGUL SYLLABLE BYU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44600 (\N{HANGUL SYLLABLE GIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Local\Temp\ipykernel_21928\574391116.py:111: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='별점', data=data, palette='viridis')
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48624 (\N{HANGUL SYLLABLE BYU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48624 (\N{HANGUL SYLLABLE BYU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48624 (\N{HANGUL SYLLABLE BYU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\wltjr\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.

# %%
import pandas as pd
import re
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.font_manager as fm

# 한글 폰트 설정
font_path = 'D:/0802pj/NanumGothic/29131424179.ttf'  # 한글 폰트 파일 경로 설정
font_name = fm.FontProperties(fname=font_path).get_name()
fm.fontManager.addfont(font_path)
plt.rcParams['font.family'] = font_name

plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# 파일을 불러옴
data = pd.read_excel('./undersample_data.xlsx')

# 리뷰 내용에서 '_ x000D' 제거
data['리뷰내용'] = data['리뷰내용'].apply(lambda x: re.sub(r'_x000D_', '', x))

# 감정 라벨 추가 (예시로 긍정=1, 부정=0으로 라벨링)
data['감정'] = data['별점'].apply(lambda x: 1 if x >= 4 else 0)

# 리뷰내용 컬럼의 모든 텍스트를 가져옴
reviews = data['리뷰내용'].dropna().tolist()
labels = data['감정'].dropna().tolist()

okt = Okt()

# 모든 문서의 명사 추출 후 하나의 텍스트로 결합
processed_docs = []
for doc in reviews:
    nouns = okt.nouns(doc)
    processed_docs.append(" ".join(nouns))

# TF-IDF 벡터화 객체 생성
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(processed_docs)

# 학습 데이터와 테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, labels, test_size=0.2, random_state=42)

# 로지스틱 회귀 모델 학습
model = LogisticRegression()
model.fit(X_train, y_train)

# 예측 및 평가
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# 감정 분석 결과 추가
data['감정_예측'] = model.predict(tfidf_matrix)

# 감정 분석 결과 출력 (데이터프레임 형태)
result_df = data[['리뷰내용', '별점', '감정', '감정_예측']]

# 긍정 리뷰 예시 10개
positive_examples = result_df[result_df['감정_예측'] == 1].head(10)

# 부정 리뷰 예시 10개
negative_examples = result_df[result_df['감정_예측'] == 0].head(10)

# 긍정, 부정 리뷰 예시 출력
print("Positive Reviews (10 examples):")
print(positive_examples)

print("\nNegative Reviews (10 examples):")
print(negative_examples)

# 감정 분석 결과와 긍정/부정 리뷰 예시를 데이터프레임으로 저장
result_df.to_excel('sentiment_analysis_results.xlsx', index=False)
positive_examples.to_excel('positive_reviews_examples.xlsx', index=False)
negative_examples.to_excel('negative_reviews_examples.xlsx', index=False)

# 추가 분석

# 리뷰 길이 분석
data['리뷰길이'] = data['리뷰내용'].apply(lambda x: len(x.split()))
plt.figure(figsize=(10, 6))
sns.histplot(data, x='리뷰길이', hue='감정', multiple='stack', palette='viridis')
plt.title('리뷰 길이 분포')
plt.xlabel('리뷰 길이 (단어 수)')
plt.ylabel('리뷰 수')
plt.show()

# 워드 클라우드 생성
positive_text = " ".join(review for review in data[data['감정'] == 1]['리뷰내용'])
negative_text = " ".join(review for review in data[data['감정'] == 0]['리뷰내용'])

wordcloud_positive = WordCloud(width=800, height=400, background_color='white', font_path=font_path).generate(positive_text)
wordcloud_negative = WordCloud(width=800, height=400, background_color='white', font_path=font_path).generate(negative_text)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.title('Positive Reviews Word Cloud')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.title('Negative Reviews Word Cloud')
plt.axis('off')

plt.show()

# 평점 분포 분석
plt.figure(figsize=(10, 6))
sns.countplot(x='별점', data=data, palette='viridis')
plt.title('평점 분포')
plt.xlabel('별점')
plt.ylabel('리뷰 수')
plt.show()

# 리뷰 시간 분석 (가정: '날짜' 컬럼이 있음)
data['날짜'] = pd.to_datetime(data['날짜'])
data['연도'] = data['날짜'].dt.year
data['월'] = data['날짜'].dt.month

plt.figure(figsize=(10, 6))
sns.countplot(x='연도', hue='감정', data=data, palette='viridis')
plt.title('연도별 리뷰 수')
plt.xlabel('연도')
plt.ylabel('리뷰 수')
plt.show()

plt.figure(figsize=(10, 6))
sns.countplot(x='월', hue='감정', data=data, palette='viridis')
plt.title('월별 리뷰 수')
plt.xlabel('월')
plt.ylabel('리뷰 수')
plt.show()
# Out:
# Accuracy: 0.9714285714285714
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.97      1.00      0.99       136
#
#     accuracy                           0.97       140
#    macro avg       0.49      0.50      0.49       140
# weighted avg       0.94      0.97      0.96       140
#
# Positive Reviews (10 examples):
#                                                 리뷰내용  별점  감정  감정_예측
# 0                                 많이 그려봐야 할 것 같습니다^^   5   1      1
# 1  문해력 수업의 기초 강의입니다.\n자세한 교안 파일이 올려져 있으면 더 좋았을 듯 ...   5   1      1
# 2                        생각보다 훨씬 재미있고 유익한 영어 연수였습니다.   5   1      1
# 3  직업눌이, 학급 경영에 따뜻함이 피어납니다. 연수 이수 후 2년째 직업놀이 중입니다...   5   1      1
# 4  한국어교원양성과정 Ⅰ연수 수강이 쉽지는 않았다.  나에겐 고등 국어 문법을 다시 공...   5   1      1
# 5  교실에 있는 스마트 기기를 어느 정도 사용한다고 생각했는데, 이 연수를 통해 보다 ...   5   1      1
# 6  입문자용으로 구글 사용의 전체적 맥락을 잡기에 좋은연수였습니다. 그리고 구글을 사용...   5   1      1
# 7                       심화해서 잘 연수하고 자격증까지 받았으면 좋겠습니다   5   1      1
# 8                                       좋은 강의 감사합니다.   5   1      1
# 9  아동인권과 더불어 교권보호에 관한 사항을 정확하게 인지하고 있어야만 무너지고 있는 ...   5   1      1
#
# Negative Reviews (10 examples):
# Empty DataFrame
# Columns: [리뷰내용, 별점, 감정, 감정_예측]
# Index: []
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\wltjr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\wltjr\AppData\Local\Temp\ipykernel_21928\666563653.py:116: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='별점', data=data, palette='viridis')
